# %%
pip install pycoingecko
# Out:
# Requirement already satisfied: pycoingecko in /Users/nathanduft/opt/anaconda3/lib/python3.8/site-packages (2.2.0)
# Requirement already satisfied: requests in /Users/nathanduft/opt/anaconda3/lib/python3.8/site-packages (from pycoingecko) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/nathanduft/opt/anaconda3/lib/python3.8/site-packages (from requests->pycoingecko) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nathanduft/opt/anaconda3/lib/python3.8/site-packages (from requests->pycoingecko) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/nathanduft/opt/anaconda3/lib/python3.8/site-packages (from requests->pycoingecko) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/nathanduft/opt/anaconda3/lib/python3.8/site-packages (from requests->pycoingecko) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
cg.ping()
# Out:
# {'gecko_says': '(V3) To the Moon!'}

# %%
cg.simple_price(ids='btc')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b6f767a10d79> in <module>
# ----> 1 cg.simple_price(ids='btc')
#
# AttributeError: 'CoinGeckoAPI' object has no attribute 'simple_price'

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()
from datetime import datetime

# %%
# /simple/price endpoint with the required parameters
>>> cg.get_price(ids='bitcoin', vs_currencies='usd')
{'bitcoin': {'usd': 3462.04}}

>>> cg.get_price(ids='bitcoin,litecoin,ethereum', vs_currencies='usd')
# OR (lists can be used for multiple-valued arguments)
>>> cg.get_price(ids=['bitcoin', 'litecoin', 'ethereum'], vs_currencies='usd')
{'bitcoin': {'usd': 3461.27}, 'ethereum': {'usd': 106.92}, 'litecoin': {'usd': 32.72}}

>>> cg.get_price(ids='bitcoin,litecoin,ethereum', vs_currencies='usd,eur')
# OR (lists can be used for multiple-valued arguments)
>>> cg.get_price(ids=['bitcoin', 'litecoin', 'ethereum'], vs_currencies=['usd', 'eur'])
{'bitcoin': {'usd': 3459.39, 'eur': 3019.33}, 'ethereum': {'usd': 106.91, 'eur': 93.31}, 'litecoin': {'usd': 32.72, 'eur': 28.56}}

# optional parameters can be passed as defined in the API doc (https://www.coingecko.com/api/docs/v3)
>>> cg.get_price(ids='bitcoin', vs_currencies='usd', include_market_cap='true', include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')
{'bitcoin': {'usd': 3458.74, 'usd_market_cap': 60574330199.29028, 'usd_24h_vol': 4182664683.6247883, 'usd_24h_change': 1.2295378479069035, 'last_updated_at': 1549071865}}
# OR (also booleans can be used for boolean type arguments)
>>> cg.get_price(ids='bitcoin', vs_currencies='usd', include_market_cap=True, include_24hr_vol=True, include_24hr_change=True, include_last_updated_at=True)
{'bitcoin': {'usd': 3458.74, 'usd_market_cap': 60574330199.29028, 'usd_24h_vol': 4182664683.6247883, 'usd_24h_change': 1.2295378479069035, 'last_updated_at': 1549071865}}
# Out:
# {'bitcoin': {'usd': 3458.74,
#   'usd_market_cap': 60574330199.29028,
#   'usd_24h_vol': 4182664683.6247883,
#   'usd_24h_change': 1.2295378479069035,
#   'last_updated_at': 1549071865}}

# %%
cg.get_price(ids='cardano,solana,ethereum, vs_currencies', vs_currencies='usd')
# Out:
# {'solana': {'usd': 40.01},
#  'cardano': {'usd': 1.47},
#  'ethereum': {'usd': 3128.97}}

# %%
timestamp =

# %%
# Historical dictionary of top 10 coins in 01 September 2013
cg.get_price(ids=['bitcoin','litecoin','Ripple', 'Namecoin', 'Peercoin','Feathercoin','Novacoin','Primecoin', 'Terracoin','Infinitecoin'], vs_currencies='usd')
# Out:
# {'litecoin': {'usd': 162.64},
#  'peercoin': {'usd': 1.01},
#  'novacoin': {'usd': 3.34},
#  'feathercoin': {'usd': 0.02316102},
#  'bitcoin': {'usd': 45721},
#  'ripple': {'usd': 0.812232},
#  'primecoin': {'usd': 0.156349},
#  'infinitecoin': {'usd': 0.00024175},
#  'terracoin': {'usd': 0.02827156},
#  'namecoin': {'usd': 1.42}}

# %%
# Defi 
cg.get_global_decentralized_finance_defi()
# Out:
# {'defi_market_cap': '103547582473.2987572331574054047',
#  'eth_market_cap': '363424424159.2744538035581550013',
#  'defi_to_eth_ratio': '28.4921913855514496260592231308171690803624739526865395839491649',
#  'trading_volume_24h': '7633517430.31882922350179026436',
#  'defi_dominance': '5.4358972398148946605488226513760057410793880375630226883987627',
#  'top_coin_name': 'Uniswap',
#  'top_coin_defi_dominance': 14.421930954325662}

# %%
# ETH and its competitors
cg.get_price(ids=['ethereum,cardano,solana,ethereum,avalanche, polkadot,binance coin, '],vs_currencies='usd')
# Out:
# {'solana': {'usd': 40.01},
#  'cardano': {'usd': 1.47},
#  'avalanche': {'usd': 3.64},
#  'polkadot': {'usd': 20.53},
#  'ethereum': {'usd': 3128.97},
#  'binancecoin': {'usd': 351.62}}

# %%
# 2016 crypto data
cg.get_price(ids=['bitcoin','dogecoin','litecoin','zcash','monero','eos','binancecoin','cardano','xrp','uniswap','sellar','filecoin','aave','eos','bancor','dash','nem'], vs_currencies='usd')
# Out:
# {'eos': {'usd': 4.5},
#  'cardano': {'usd': 1.47},
#  'litecoin': {'usd': 162.76},
#  'filecoin': {'usd': 68.55},
#  'bancor': {'usd': 3.97},
#  'uniswap': {'usd': 29.35},
#  'aave': {'usd': 374.68},
#  'dash': {'usd': 176.28},
#  'bitcoin': {'usd': 45741},
#  'dogecoin': {'usd': 0.254029},
#  'monero': {'usd': 266.6},
#  'binancecoin': {'usd': 351.8},
#  'zcash': {'usd': 130.23},
#  'nem': {'usd': 0.181826}}

# %%
data = cg.get_coin_history_by_id(id='bitcoin',date='10-11-2020', localization='false')

# %%
data
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png?1547033579',
#   'small': 'https://assets.coingecko.com/coins/images/1/small/bitcoin.png?1547033579'},
#  'market_data': {'current_price': {'aed': 56326.52786980459,
#    'ars': 1215617.24070744,
#    'aud': 21082.415040368352,
#    'bch': 58.03006574753659,
#    'bdt': 1301263.6700267561,
#    'bhd': 5783.172237724017,
#    'bmd': 15335.342198178862,
#    'bnb': 548.489735186886,
#    'brl': 82599.20481248871,
#    'btc': 1.0,
#    'cad': 19947.369687570146,
#    'chf': 13994.941278004791,
#    'clp': 11618071.458796967,
#    'cny': 101667.18463704686,
#    'czk': 343849.04276756675,
#    'dkk': 96585.05223257001,
#    'dot': 3530.9500103196324,
#    'eos': 6136.865733687228,
#    'eth': 34.44319624770999,
#    'eur': 12970.985144090215,
#    'gbp': 11647.729136493797,
#    'hkd': 118887.24039138111,
#    'huf': 4657417.832667269,
#    'idr': 218928088.9852976,
#    'ils': 51595.14541208477,
#    'inr': 1134162.0370875916,
#    'jpy': 1612209.6370241605,
#    'krw': 17170829.781274468,
#    'kwd': 4683.38283663943,
#    'lkr': 2831336.1357028554,
#    'ltc': 258.8060744084482,
#    'mmk': 19765626.652002573,
#    'mxn': 311877.92135280336,
#    'myr': 62999.11928433854,
#    'ngn': 5871717.3380903015,
#    'nok': 138488.39939348536,
#    'nzd': 22479.250019831645,
#    'php': 740617.5757641097,
#    'pkr': 2439015.894747048,
#    'pln': 58087.76125058096,
#    'rub': 1169868.8478618292,
#    'sar': 57513.391343890435,
#    'sek': 132177.69138414445,
#    'sgd': 20664.373612046023,
#    'thb': 468954.7644203092,
#    'try': 124294.78875730299,
#    'twd': 439265.5419246347,
#    'uah': 431086.5291752898,
#    'usd': 15335.342198178862,
#    'vef': 3810643025.7843738,
#    'vnd': 357418047.8297312,
#    'xag': 632.0976554477277,
#    'xau': 8.200114180210191,
#    'xdr': 10769.259394013277,
#    'xlm': 192403.97515238347,
#    'xrp': 61162.052643197574,
#    'yfi': 1.021790626535115,
#    'zar': 236109.06262004064,
#    'bits': 1000000.0,
#    'link': 1223.3665779769478,
#    'sats': 100000000.0},
#   'market_cap': {'aed': 1044201901812.6936,
#    'ars': 22535559755379.1,
#    'aud': 390833568347.0833,
#    'bch': 1075782713.8920283,
#    'bdt': 24123304779986.574,
#    'bhd': 107210575150.31131,
#    'bmd': 284292217075.7686,
#    'bnb': 10168104555.11704,
#    'brl': 1531254455321.2866,
#    'btc': 18538368.0,
#    'cad': 369791679900.22046,
#    'chf': 259443371550.0431,
#    'clp': 215380084153475.06,
#    'cny': 1884743682325.522,
#    'czk': 6374400091272.89,
#    'dkk': 1790529241586.6045,
#    'dot': 65458050680.909134,
#    'eos': 113767475337.68382,
#    'eth': 638520647.136267,
#    'eur': 240460895923.67734,
#    'gbp': 215929889096.6443,
#    'hkd': 2203975412879.8867,
#    'huf': 86340925711748.25,
#    'idr': 4058569479146193.5,
#    'ils': 956489792662.7391,
#    'inr': 21025513215159.43,
#    'jpy': 29887735544300.305,
#    'krw': 318319161350625.6,
#    'kwd': 86822274510.50563,
#    'lkr': 52488351215357.46,
#    'ltc': 4797842248.019195,
#    'mmk': 366422460625431.56,
#    'mxn': 5781707677113.327,
#    'myr': 1167900856968.9646,
#    'ngn': 108852056805498.42,
#    'nok': 2567348911687.409,
#    'nzd': 416728609231.64624,
#    'php': 13729841166782.947,
#    'pkr': 45215374214670.04,
#    'pln': 1076852294359.41,
#    'rub': 21687459213398.598,
#    'sar': 1066204413661.0553,
#    'sek': 2450358684269.698,
#    'sgd': 383083762509.5983,
#    'thb': 8693655998176.999,
#    'try': 2304222534465.1455,
#    'twd': 8143266265918.307,
#    'uah': 7991640717694.259,
#    'usd': 284292217075.7686,
#    'vef': 70643102728624216,
#    'vnd': 6625947300509158,
#    'xag': 11718058948.62718,
#    'xau': 152016734.31475484,
#    'xdr': 199644493733.67517,
#    'xlm': 3566855696037.741,
#    'xrp': 1133844639534.9692,
#    'yfi': 18942330.653658528,
#    'zar': 4377076690985.357,
#    'bits': 18538368000000.0,
#    'link': 22679219821.43736,
#    'sats': 1853836800000000},
#   'total_volume': {'aed': 108359588578.09189,
#    'ars': 2338574541217.3315,
#    'aud': 40557831387.85573,
#    'bch': 111636812.83705766,
#    'bdt': 2503339034879.6304,
#    'bhd': 11125524474.089893,
#    'bmd': 29501754042.78257,
#    'bnb': 1055171058.6801296,
#    'brl': 158902318123.4813,
#    'btc': 1924639.305469634,
#    'cad': 38374259062.37918,
#    'chf': 26923123728.919025,
#    'clp': 22350560046166.02,
#    'cny': 195584828602.03186,
#    'czk': 661488329147.2714,
#    'dkk': 185807947312.25302,
#    'dot': 6792754761.88467,
#    'eos': 11805951320.103003,
#    'eth': 66260973.57435572,
#    'eur': 24953262109.728436,
#    'gbp': 22407614756.88489,
#    'hkd': 228712348216.6709,
#    'huf': 8959825845303.688,
#    'idr': 421168471549834.2,
#    'ils': 99257471406.7801,
#    'inr': 2181873024443.6846,
#    'jpy': 3101529236337.4106,
#    'krw': 33032819898717.54,
#    'kwd': 9009776681.157717,
#    'lkr': 5446854801705.539,
#    'ltc': 497884758.8339333,
#    'mmk': 38024626281772.57,
#    'mxn': 599983072318.8782,
#    'myr': 121196155783.15501,
#    'ngn': 11295865359799.629,
#    'nok': 266420575679.78058,
#    'nzd': 43245028156.59657,
#    'php': 1424781871678.7017,
#    'pkr': 4692118773965.779,
#    'pln': 111747806026.39725,
#    'rub': 2250564908556.8955,
#    'sar': 110642847330.47899,
#    'sek': 254280190866.61987,
#    'sgd': 39753613572.649536,
#    'thb': 902163638628.2904,
#    'try': 239115256727.237,
#    'twd': 845048242801.4629,
#    'uah': 829313659293.2701,
#    'usd': 29501754042.78257,
#    'vef': 7330821304064920,
#    'vnd': 687592047262983.6,
#    'xag': 1216013918.7668674,
#    'xau': 15775177.92175668,
#    'xdr': 20717636278.298054,
#    'xlm': 370142033900.83765,
#    'xrp': 117662052174.20015,
#    'yfi': 1965695.6693695087,
#    'zar': 454220805944.2968,
#    'bits': 1924639305469.634,
#    'link': 2353482525.608233,
#    'sats': 192463930546963.4}},
#  'community_data': {'facebook_likes': None,
#   'twitter_followers': 72617,
#   'reddit_average_posts_48h': 6.727,
#   'reddit_average_comments_48h': 366.273,
#   'reddit_subscribers': 1747658,
#   'reddit_accounts_active_48h': '4851.91666666667'},
#  'developer_data': {'forks': 26617,
#   'stars': 45862,
#   'subscribers': 3589,
#   'total_issues': 5789,
#   'closed_issues': 5211,
#   'pull_requests_merged': 8022,
#   'pull_request_contributors': 696,
#   'code_additions_deletions_4_weeks': {'additions': 10865, 'deletions': -7137},
#   'commit_count_4_weeks': 280},
#  'public_interest_stats': {'alexa_rank': 9292, 'bing_matches': None}}

# %%
cg.get_coins_markets(vs_currency='usd')
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 45743,
#   'market_cap': 860719961376,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 962386057910,
#   'total_volume': 41806722102,
#   'high_24h': 46456,
#   'low_24h': 43377,
#   'price_change_24h': 2054.86,
#   'price_change_percentage_24h': 4.70348,
#   'market_cap_change_24h': 44994047773,
#   'market_cap_change_percentage_24h': 5.51583,
#   'circulating_supply': 18781568.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 64805,
#   'ath_change_percentage': -29.46702,
#   'ath_date': '2021-04-14T11:54:46.763Z',
#   'atl': 67.81,
#   'atl_change_percentage': 67308.0116,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:53.462Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880',
#   'current_price': 3133.69,
#   'market_cap': 365514142395,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': None,
#   'total_volume': 36662744956,
#   'high_24h': 3181.83,
#   'low_24h': 2908.29,
#   'price_change_24h': 173.55,
#   'price_change_percentage_24h': 5.86275,
#   'market_cap_change_24h': 21354637325,
#   'market_cap_change_percentage_24h': 6.20487,
#   'circulating_supply': 117042723.5615,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4356.99,
#   'ath_change_percentage': -28.35379,
#   'ath_date': '2021-05-12T14:41:48.623Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 720863.30966,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 90.6893672248766,
#    'currency': 'btc',
#    'percentage': 9068.93672248766},
#   'last_updated': '2021-08-10T05:33:50.929Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://assets.coingecko.com/coins/images/325/large/Tether-logo.png?1598003707',
#   'current_price': 1.0,
#   'market_cap': 62938643078,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': None,
#   'total_volume': 71763861602,
#   'high_24h': 1.01,
#   'low_24h': 0.994584,
#   'price_change_24h': -0.002674551994,
#   'price_change_percentage_24h': -0.26673,
#   'market_cap_change_24h': 77151823,
#   'market_cap_change_percentage_24h': 0.12273,
#   'circulating_supply': 62788235031.2064,
#   'total_supply': 62788235031.2064,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.41674,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.67283,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:05:28.860Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'Binance Coin',
#   'image': 'https://assets.coingecko.com/coins/images/825/large/binance-coin-logo.png?1547034615',
#   'current_price': 352.25,
#   'market_cap': 54479395945,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 60120046537,
#   'total_volume': 1448085101,
#   'high_24h': 356.69,
#   'low_24h': 339.87,
#   'price_change_24h': 10.4,
#   'price_change_percentage_24h': 3.04362,
#   'market_cap_change_24h': 2208789001,
#   'market_cap_change_percentage_24h': 4.22568,
#   'circulating_supply': 154533651.9,
#   'total_supply': 170533651.9,
#   'max_supply': 170533651.9,
#   'ath': 686.31,
#   'ath_change_percentage': -48.83032,
#   'ath_date': '2021-05-10T07:24:17.097Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 881871.96657,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:31.618Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860',
#   'current_price': 1.47,
#   'market_cap': 47013809423,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 65976287944,
#   'total_volume': 2037623570,
#   'high_24h': 1.5,
#   'low_24h': 1.41,
#   'price_change_24h': 0.051485,
#   'price_change_percentage_24h': 3.6228,
#   'market_cap_change_24h': 1677333447,
#   'market_cap_change_percentage_24h': 3.69974,
#   'circulating_supply': 32066390668.4135,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 2.45,
#   'ath_change_percentage': -39.89023,
#   'ath_date': '2021-05-16T07:44:28.033Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 7535.12828,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:56.924Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731',
#   'current_price': 0.812624,
#   'market_cap': 37629488637,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 81067275512,
#   'total_volume': 4028349482,
#   'high_24h': 0.825989,
#   'low_24h': 0.785051,
#   'price_change_24h': 0.01999519,
#   'price_change_percentage_24h': 2.52264,
#   'market_cap_change_24h': 1539317205,
#   'market_cap_change_percentage_24h': 4.2652,
#   'circulating_supply': 46417606117.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -76.10581,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 30129.69744,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:56.138Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256',
#   'current_price': 0.254278,
#   'market_cap': 33011292533,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': None,
#   'total_volume': 3645254733,
#   'high_24h': 0.264288,
#   'low_24h': 0.235556,
#   'price_change_24h': 0.01248328,
#   'price_change_percentage_24h': 5.16277,
#   'market_cap_change_24h': 1641521800,
#   'market_cap_change_percentage_24h': 5.23281,
#   'circulating_supply': 130799611235.772,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -65.31535,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 291884.27427,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:51.810Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USD Coin',
#   'image': 'https://assets.coingecko.com/coins/images/6319/large/USD_Coin_icon.png?1547042389',
#   'current_price': 1.0,
#   'market_cap': 27896976337,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': None,
#   'total_volume': 3527996533,
#   'high_24h': 1.01,
#   'low_24h': 0.987095,
#   'price_change_24h': 0.00063288,
#   'price_change_percentage_24h': 0.06327,
#   'market_cap_change_24h': 139882049,
#   'market_cap_change_percentage_24h': 0.50395,
#   'circulating_supply': 27876725044.7976,
#   'total_supply': 27875517918.5576,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.57446,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.891848,
#   'atl_change_percentage': 12.32751,
#   'atl_date': '2021-05-19T13:14:05.611Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:48.316Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://assets.coingecko.com/coins/images/12171/large/aJGBjJFU_400x400.jpg?1597804776',
#   'current_price': 20.54,
#   'market_cap': 20792788957,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': None,
#   'total_volume': 985164672,
#   'high_24h': 21.08,
#   'low_24h': 19.21,
#   'price_change_24h': 1.06,
#   'price_change_percentage_24h': 5.44974,
#   'market_cap_change_24h': 1078007393,
#   'market_cap_change_percentage_24h': 5.46802,
#   'circulating_supply': 1017341188.89228,
#   'total_supply': 1098291054.46107,
#   'max_supply': None,
#   'ath': 49.35,
#   'ath_change_percentage': -58.40412,
#   'ath_date': '2021-05-15T03:59:58.961Z',
#   'atl': 2.7,
#   'atl_change_percentage': 660.98165,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:46.098Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://assets.coingecko.com/coins/images/12504/large/uniswap-uni.png?1600306604',
#   'current_price': 29.43,
#   'market_cap': 14956095043,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 28769611407,
#   'total_volume': 651813613,
#   'high_24h': 29.43,
#   'low_24h': 25.91,
#   'price_change_24h': 3.05,
#   'price_change_percentage_24h': 11.56562,
#   'market_cap_change_24h': 1352088850,
#   'market_cap_change_percentage_24h': 9.9389,
#   'circulating_supply': 519857388.1320768,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -34.74767,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 2745.1668,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:44.417Z'},
#  {'id': 'binance-usd',
#   'symbol': 'busd',
#   'name': 'Binance USD',
#   'image': 'https://assets.coingecko.com/coins/images/9576/large/BUSD.png?1568947766',
#   'current_price': 1.0,
#   'market_cap': 12163328406,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': None,
#   'total_volume': 4713406606,
#   'high_24h': 1.02,
#   'low_24h': 0.99296,
#   'price_change_24h': 0.00060285,
#   'price_change_percentage_24h': 0.06018,
#   'market_cap_change_24h': -88380042.71197891,
#   'market_cap_change_percentage_24h': -0.72137,
#   'circulating_supply': 12160338142.57,
#   'total_supply': 12160338142.57,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.1999,
#   'ath_date': '2020-03-13T02:35:42.953Z',
#   'atl': 0.901127,
#   'atl_change_percentage': 11.17745,
#   'atl_date': '2021-05-19T13:04:37.445Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:56.666Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1594689492',
#   'current_price': 583.11,
#   'market_cap': 11060657518,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 12346415493,
#   'total_volume': 3864524692,
#   'high_24h': 600.27,
#   'low_24h': 550.59,
#   'price_change_24h': 28.04,
#   'price_change_percentage_24h': 5.05224,
#   'market_cap_change_24h': 733110321,
#   'market_cap_change_percentage_24h': 7.09859,
#   'circulating_supply': 18813056.1467892,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -84.61347,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 657.14261,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:56.602Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://assets.coingecko.com/coins/images/2/large/litecoin.png?1547033580',
#   'current_price': 162.86,
#   'market_cap': 10923654964,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': None,
#   'total_volume': 3125935035,
#   'high_24h': 169.58,
#   'low_24h': 147.38,
#   'price_change_24h': 14.21,
#   'price_change_percentage_24h': 9.56235,
#   'market_cap_change_24h': 1107878452,
#   'market_cap_change_percentage_24h': 11.28671,
#   'circulating_supply': 66752614.5153875,
#   'total_supply': 84000000.0,
#   'max_supply': None,
#   'ath': 410.26,
#   'ath_change_percentage': -60.39168,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 14044.41264,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:39.703Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://assets.coingecko.com/coins/images/4128/large/coinmarketcap-solana-200.png?1616489452',
#   'current_price': 40.0,
#   'market_cap': 10878405978,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 19496692567,
#   'total_volume': 464362867,
#   'high_24h': 40.47,
#   'low_24h': 37.08,
#   'price_change_24h': 2.32,
#   'price_change_percentage_24h': 6.14844,
#   'market_cap_change_24h': 724504888,
#   'market_cap_change_percentage_24h': 7.13524,
#   'circulating_supply': 272637122.50492,
#   'total_supply': 488630611.0,
#   'max_supply': 488630611.0,
#   'ath': 58.03,
#   'ath_change_percentage': -31.06398,
#   'ath_date': '2021-05-18T16:59:08.690Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 7888.43935,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:55.295Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1547034700',
#   'current_price': 24.03,
#   'market_cap': 10646496891,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 23951109256,
#   'total_volume': 940973497,
#   'high_24h': 24.63,
#   'low_24h': 22.5,
#   'price_change_24h': 1.28,
#   'price_change_percentage_24h': 5.60632,
#   'market_cap_change_24h': 619617145,
#   'market_cap_change_percentage_24h': 6.17956,
#   'circulating_supply': 444509553.9174637,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -54.45501,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 16096.61418,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:43.026Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1548822744',
#   'current_price': 45766,
#   'market_cap': 8939199067,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 8939199067,
#   'total_volume': 420702867,
#   'high_24h': 46387,
#   'low_24h': 43378,
#   'price_change_24h': 2107.34,
#   'price_change_percentage_24h': 4.82683,
#   'market_cap_change_24h': 503079817,
#   'market_cap_change_percentage_24h': 5.9634,
#   'circulating_supply': 194523.30983435,
#   'total_supply': 194523.30983435,
#   'max_supply': 194523.30983435,
#   'ath': 64565,
#   'ath_change_percentage': -29.22157,
#   'ath_date': '2021-04-14T12:00:05.340Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 1355.7419,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:00.553Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://assets.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1620703073',
#   'current_price': 70.84,
#   'market_cap': 8623635859,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 29556986270,
#   'total_volume': 1125446947,
#   'high_24h': 70.69,
#   'low_24h': 59.86,
#   'price_change_24h': 8.67,
#   'price_change_percentage_24h': 13.93983,
#   'market_cap_change_24h': 653823783,
#   'market_cap_change_percentage_24h': 8.20375,
#   'circulating_supply': 136899213.55,
#   'total_supply': 469213710.0,
#   'max_supply': 469213710.0,
#   'ath': 700.65,
#   'ath_change_percentage': -89.97088,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 27.44,
#   'atl_change_percentage': 156.11442,
#   'atl_date': '2021-07-20T10:14:50.919Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:49.847Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://assets.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1547034169',
#   'current_price': 58.51,
#   'market_cap': 7544551700,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': None,
#   'total_volume': 3469348595,
#   'high_24h': 60.25,
#   'low_24h': 56.27,
#   'price_change_24h': 1.07,
#   'price_change_percentage_24h': 1.87035,
#   'market_cap_change_24h': 219696046,
#   'market_cap_change_percentage_24h': 2.99932,
#   'circulating_supply': 128865735.089617,
#   'total_supply': 210700000.0,
#   'max_supply': None,
#   'ath': 167.09,
#   'ath_change_percentage': -65.1294,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 9373.18245,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 129.01442593147152,
#    'currency': 'usd',
#    'percentage': 12901.44259314715},
#   'last_updated': '2021-08-10T05:33:54.119Z'},
#  {'id': 'matic-network',
#   'symbol': 'matic',
#   'name': 'Polygon',
#   'image': 'https://assets.coingecko.com/coins/images/4713/large/matic-token-icon.png?1624446912',
#   'current_price': 1.13,
#   'market_cap': 7241539322,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 11232877465,
#   'total_volume': 637176181,
#   'high_24h': 1.15,
#   'low_24h': 1.07,
#   'price_change_24h': 0.04768367,
#   'price_change_percentage_24h': 4.40939,
#   'market_cap_change_24h': 360895996,
#   'market_cap_change_percentage_24h': 5.24509,
#   'circulating_supply': 6446735794.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.62,
#   'ath_change_percentage': -56.94599,
#   'ath_date': '2021-05-18T19:38:18.813Z',
#   'atl': 0.00314376,
#   'atl_change_percentage': 35786.91121,
#   'atl_date': '2019-05-10T00:00:00.000Z',
#   'roi': {'times': 428.314164934446,
#    'currency': 'usd',
#    'percentage': 42831.4164934446},
#   'last_updated': '2021-08-10T05:33:48.839Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://assets.coingecko.com/coins/images/100/large/Stellar_symbol_black_RGB.png?1552356157',
#   'current_price': 0.300341,
#   'market_cap': 7028253844,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 14987877466,
#   'total_volume': 560547110,
#   'high_24h': 0.304939,
#   'low_24h': 0.2861,
#   'price_change_24h': 0.01132316,
#   'price_change_percentage_24h': 3.9178,
#   'market_cap_change_24h': 351267520,
#   'market_cap_change_percentage_24h': 5.26087,
#   'circulating_supply': 23447306958.4097,
#   'total_supply': 50001802920.6693,
#   'max_supply': 50001802920.6693,
#   'ath': 0.875563,
#   'ath_change_percentage': -65.77648,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 62835.05523,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:53.803Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://assets.coingecko.com/coins/images/1167/large/VeChain-Logo-768x725.png?1547035194',
#   'current_price': 0.104804,
#   'market_cap': 6849610711,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': None,
#   'total_volume': 809857499,
#   'high_24h': 0.107365,
#   'low_24h': 0.098735,
#   'price_change_24h': 0.00431434,
#   'price_change_percentage_24h': 4.29331,
#   'market_cap_change_24h': 338094800,
#   'market_cap_change_percentage_24h': 5.19226,
#   'circulating_supply': 65241752869.0,
#   'total_supply': 86712634466.0,
#   'max_supply': None,
#   'ath': 0.280991,
#   'ath_change_percentage': -62.71787,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 5364.3808,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 10.704392635024277,
#    'currency': 'eth',
#    'percentage': 1070.4392635024278},
#   'last_updated': '2021-08-10T05:32:44.075Z'},
#  {'id': 'theta-token',
#   'symbol': 'theta',
#   'name': 'Theta Network',
#   'image': 'https://assets.coingecko.com/coins/images/2538/large/theta-token-logo.png?1548387191',
#   'current_price': 6.69,
#   'market_cap': 6716740518,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': None,
#   'total_volume': 341794571,
#   'high_24h': 6.9,
#   'low_24h': 6.36,
#   'price_change_24h': 0.276747,
#   'price_change_percentage_24h': 4.31543,
#   'market_cap_change_24h': 408538568,
#   'market_cap_change_percentage_24h': 6.47631,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 15.72,
#   'ath_change_percentage': -57.53411,
#   'ath_date': '2021-04-16T13:15:11.190Z',
#   'atl': 0.04039979,
#   'atl_change_percentage': 16423.6422,
#   'atl_date': '2020-03-13T02:24:16.483Z',
#   'roi': {'times': 43.59808951789912,
#    'currency': 'usd',
#    'percentage': 4359.808951789912},
#   'last_updated': '2021-08-10T05:32:09.551Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png?1602753933',
#   'current_price': 68.54,
#   'market_cap': 6462184745,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 133800194756,
#   'total_volume': 694359589,
#   'high_24h': 69.19,
#   'low_24h': 63.05,
#   'price_change_24h': 4.47,
#   'price_change_percentage_24h': 6.97824,
#   'market_cap_change_24h': 403813703,
#   'market_cap_change_percentage_24h': 6.66538,
#   'circulating_supply': 95274291.0,
#   'total_supply': 1972662825.0,
#   'max_supply': 1972662825.0,
#   'ath': 236.84,
#   'ath_change_percentage': -71.05125,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 20.06,
#   'atl_change_percentage': 241.79306,
#   'atl_date': '2020-12-29T22:32:28.483Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:43.379Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://assets.coingecko.com/coins/images/4463/large/okb_token.png?1548386209',
#   'current_price': 23.67,
#   'market_cap': 6398687891,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': None,
#   'total_volume': 943125867,
#   'high_24h': 24.41,
#   'low_24h': 22.91,
#   'price_change_24h': 0.649748,
#   'price_change_percentage_24h': 2.82197,
#   'market_cap_change_24h': 566281997,
#   'market_cap_change_percentage_24h': 9.70924,
#   'circulating_supply': 267436117.72,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 44.01,
#   'ath_change_percentage': -46.4292,
#   'ath_date': '2021-05-03T01:03:16.108Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 3960.22514,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:05.520Z'},
#  {'id': 'terra-luna',
#   'symbol': 'luna',
#   'name': 'Terra',
#   'image': 'https://assets.coingecko.com/coins/images/8284/large/luna1557227471663.png?1567147072',
#   'current_price': 14.03,
#   'market_cap': 5800858795,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': None,
#   'total_volume': 402799116,
#   'high_24h': 14.37,
#   'low_24h': 13.38,
#   'price_change_24h': 0.5111,
#   'price_change_percentage_24h': 3.78123,
#   'market_cap_change_24h': 226015676,
#   'market_cap_change_percentage_24h': 4.05421,
#   'circulating_supply': 413151169.005121,
#   'total_supply': 994734901.61111,
#   'max_supply': None,
#   'ath': 22.36,
#   'ath_change_percentage': -37.11027,
#   'ath_date': '2021-03-21T11:59:15.174Z',
#   'atl': 0.121798,
#   'atl_change_percentage': 11443.91676,
#   'atl_date': '2020-03-18T17:03:01.083Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:29.647Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://assets.coingecko.com/coins/images/9956/large/dai-multi-collateral-mcd.png?1574218774',
#   'current_price': 1.0,
#   'market_cap': 5559768484,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 5559768484,
#   'total_volume': 654114192,
#   'high_24h': 1.01,
#   'low_24h': 0.995531,
#   'price_change_24h': -0.002071939232,
#   'price_change_percentage_24h': -0.2067,
#   'market_cap_change_24h': 3863785,
#   'market_cap_change_percentage_24h': 0.06954,
#   'circulating_supply': 5549744181.506,
#   'total_supply': 5549875681.13136,
#   'max_supply': 5549875681.13136,
#   'ath': 1.22,
#   'ath_change_percentage': -17.93676,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.903243,
#   'atl_change_percentage': 10.7447,
#   'atl_date': '2019-11-25T00:04:18.137Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:05:27.629Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://assets.coingecko.com/coins/images/1094/large/tron-logo.png?1547035066',
#   'current_price': 0.073974,
#   'market_cap': 5301834919,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': None,
#   'total_volume': 1315904538,
#   'high_24h': 0.074739,
#   'low_24h': 0.070604,
#   'price_change_24h': 0.00250855,
#   'price_change_percentage_24h': 3.51015,
#   'market_cap_change_24h': 215666386,
#   'market_cap_change_percentage_24h': 4.24025,
#   'circulating_supply': 71660220128.0,
#   'total_supply': 100850743812.0,
#   'max_supply': None,
#   'ath': 0.231673,
#   'ath_change_percentage': -68.13179,
#   'ath_date': '2018-01-05T00:00:00.000Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 3991.7944,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 37.93380898832142,
#    'currency': 'usd',
#    'percentage': 3793.3808988321416},
#   'last_updated': '2021-08-10T05:33:51.978Z'},
#  {'id': 'compound-usd-coin',
#   'symbol': 'cusdc',
#   'name': 'cUSDC',
#   'image': 'https://assets.coingecko.com/coins/images/9442/large/Compound_USDC.png?1567581577',
#   'current_price': 0.02212811,
#   'market_cap': 5144917914,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': None,
#   'total_volume': 15918954,
#   'high_24h': 0.02281269,
#   'low_24h': 0.02178964,
#   'price_change_24h': 4.781e-05,
#   'price_change_percentage_24h': 0.21652,
#   'market_cap_change_24h': 23581713,
#   'market_cap_change_percentage_24h': 0.46046,
#   'circulating_supply': 232080373213.19,
#   'total_supply': 232105118656.101,
#   'max_supply': None,
#   'ath': 0.058843,
#   'ath_change_percentage': -62.39492,
#   'ath_date': '2020-10-21T11:24:27.820Z',
#   'atl': 0.00620705,
#   'atl_change_percentage': 256.49943,
#   'atl_date': '2021-03-04T08:11:37.438Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:18:11.801Z'},
#  {'id': 'ftx-token',
#   'symbol': 'ftt',
#   'name': 'FTX Token',
#   'image': 'https://assets.coingecko.com/coins/images/9026/large/F.png?1609051564',
#   'current_price': 48.04,
#   'market_cap': 5099728313,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 16170033248,
#   'total_volume': 163426818,
#   'high_24h': 49.32,
#   'low_24h': 43.0,
#   'price_change_24h': 4.52,
#   'price_change_percentage_24h': 10.3838,
#   'market_cap_change_24h': 536322534,
#   'market_cap_change_percentage_24h': 11.75268,
#   'circulating_supply': 106354892.31874424,
#   'total_supply': 337226228.385972,
#   'max_supply': 337226228.385972,
#   'ath': 63.12,
#   'ath_change_percentage': -24.04365,
#   'ath_date': '2021-05-12T03:59:29.290Z',
#   'atl': 1.15,
#   'atl_change_percentage': 4069.85178,
#   'atl_date': '2019-09-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:36.201Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://assets.coingecko.com/coins/images/12645/large/AAVE.png?1601374110',
#   'current_price': 375.84,
#   'market_cap': 4839118598,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 5983954304,
#   'total_volume': 319232377,
#   'high_24h': 383.75,
#   'low_24h': 352.16,
#   'price_change_24h': 17.71,
#   'price_change_percentage_24h': 4.94656,
#   'market_cap_change_24h': 254099904,
#   'market_cap_change_percentage_24h': 5.54196,
#   'circulating_supply': 12938918.585115058,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -43.41821,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 1338.7042,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:47.770Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1547033729',
#   'current_price': 265.86,
#   'market_cap': 4824752519,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': None,
#   'total_volume': 232349542,
#   'high_24h': 271.75,
#   'low_24h': 255.66,
#   'price_change_24h': 5.13,
#   'price_change_percentage_24h': 1.96871,
#   'market_cap_change_24h': 185398710,
#   'market_cap_change_percentage_24h': 3.99622,
#   'circulating_supply': 17970096.5485651,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -50.79398,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 123343.86121,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:00.325Z'},
#  {'id': 'compound-ether',
#   'symbol': 'ceth',
#   'name': 'cETH',
#   'image': 'https://assets.coingecko.com/coins/images/10643/large/ceth2.JPG?1581389598',
#   'current_price': 62.67,
#   'market_cap': 4687115615,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': None,
#   'total_volume': 13866909,
#   'high_24h': 63.62,
#   'low_24h': 58.36,
#   'price_change_24h': 3.36,
#   'price_change_percentage_24h': 5.6569,
#   'market_cap_change_24h': 233685878,
#   'market_cap_change_percentage_24h': 5.24732,
#   'circulating_supply': 75071336.3202034,
#   'total_supply': 75067030.1430029,
#   'max_supply': None,
#   'ath': 87.15,
#   'ath_change_percentage': -28.08858,
#   'ath_date': '2021-05-12T14:49:23.076Z',
#   'atl': 1.89,
#   'atl_change_percentage': 3222.28305,
#   'atl_date': '2020-03-13T02:22:33.711Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:18:11.487Z'},
#  {'id': 'cdai',
#   'symbol': 'cdai',
#   'name': 'cDAI',
#   'image': 'https://assets.coingecko.com/coins/images/9281/large/cDAI.png?1576467585',
#   'current_price': 0.02157284,
#   'market_cap': 4427759512,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': None,
#   'total_volume': 79567570,
#   'high_24h': 0.02194816,
#   'low_24h': 0.02123582,
#   'price_change_24h': 2.782e-05,
#   'price_change_percentage_24h': 0.12912,
#   'market_cap_change_24h': -9617778.914761543,
#   'market_cap_change_percentage_24h': -0.21674,
#   'circulating_supply': 204800919756.638,
#   'total_supply': 204774086235.187,
#   'max_supply': None,
#   'ath': 0.03159087,
#   'ath_change_percentage': -31.71179,
#   'ath_date': '2020-10-12T21:29:00.007Z',
#   'atl': 0.00728854,
#   'atl_change_percentage': 195.98283,
#   'atl_date': '2020-03-18T04:29:40.819Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:18:12.652Z'},
#  {'id': 'eos',
#   'symbol': 'eos',
#   'name': 'EOS',
#   'image': 'https://assets.coingecko.com/coins/images/738/large/eos-eos-logo.png?1547034481',
#   'current_price': 4.5,
#   'market_cap': 4329661640,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': None,
#   'total_volume': 1486067422,
#   'high_24h': 4.56,
#   'low_24h': 4.25,
#   'price_change_24h': 0.224645,
#   'price_change_percentage_24h': 5.25254,
#   'market_cap_change_24h': 261067588,
#   'market_cap_change_percentage_24h': 6.41665,
#   'circulating_supply': 962080572.192,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 22.71,
#   'ath_change_percentage': -80.1923,
#   'ath_date': '2018-04-29T07:50:33.540Z',
#   'atl': 0.5024,
#   'atl_change_percentage': 795.41814,
#   'atl_date': '2017-10-23T00:00:00.000Z',
#   'roi': {'times': 3.5470014464678616,
#    'currency': 'usd',
#    'percentage': 354.70014464678616},
#   'last_updated': '2021-08-10T05:33:48.832Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos',
#   'image': 'https://assets.coingecko.com/coins/images/1481/large/cosmos_hub.png?1555657960',
#   'current_price': 13.63,
#   'market_cap': 3835405459,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': None,
#   'total_volume': 309368240,
#   'high_24h': 13.97,
#   'low_24h': 13.02,
#   'price_change_24h': 0.53343,
#   'price_change_percentage_24h': 4.07243,
#   'market_cap_change_24h': 247717916,
#   'market_cap_change_percentage_24h': 6.90467,
#   'circulating_supply': 277279009.628656,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 31.7,
#   'ath_change_percentage': -56.86538,
#   'ath_date': '2021-05-07T16:18:33.469Z',
#   'atl': 1.16,
#   'atl_change_percentage': 1078.77731,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'roi': {'times': 135.3198734763033,
#    'currency': 'usd',
#    'percentage': 13531.98734763033},
#   'last_updated': '2021-08-10T05:33:38.088Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://assets.coingecko.com/coins/images/11939/large/shiba.png?1622619446',
#   'current_price': 7.64e-06,
#   'market_cap': 3785164778,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': None,
#   'total_volume': 448493059,
#   'high_24h': 7.86e-06,
#   'low_24h': 7.2e-06,
#   'price_change_24h': 3.02849e-07,
#   'price_change_percentage_24h': 4.12579,
#   'market_cap_change_24h': 118886934,
#   'market_cap_change_percentage_24h': 3.24271,
#   'circulating_supply': 497730966630395.75,
#   'total_supply': 1000000000000000.0,
#   'max_supply': None,
#   'ath': 3.791e-05,
#   'ath_change_percentage': -79.95972,
#   'ath_date': '2021-05-10T22:53:42.945Z',
#   'atl': 5.6e-11,
#   'atl_change_percentage': 13479002.75642,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:57.946Z'},
#  {'id': 'pancakeswap-token',
#   'symbol': 'cake',
#   'name': 'PancakeSwap',
#   'image': 'https://assets.coingecko.com/coins/images/12632/large/IMG_0440.PNG?1602654093',
#   'current_price': 18.16,
#   'market_cap': 3755645235,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': None,
#   'total_volume': 208259992,
#   'high_24h': 18.65,
#   'low_24h': 17.69,
#   'price_change_24h': 0.404685,
#   'price_change_percentage_24h': 2.2791,
#   'market_cap_change_24h': 165931308,
#   'market_cap_change_percentage_24h': 4.62241,
#   'circulating_supply': 207221516.03763,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 43.96,
#   'ath_change_percentage': -58.76167,
#   'ath_date': '2021-04-30T10:08:22.934Z',
#   'atl': 0.194441,
#   'atl_change_percentage': 9224.32567,
#   'atl_date': '2020-11-03T14:29:34.165Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:00.042Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Crypto.com Coin',
#   'image': 'https://assets.coingecko.com/coins/images/7310/large/cypto.png?1547043960',
#   'current_price': 0.141706,
#   'market_cap': 3586306398,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': None,
#   'total_volume': 40334602,
#   'high_24h': 0.144094,
#   'low_24h': 0.133119,
#   'price_change_24h': 0.00755744,
#   'price_change_percentage_24h': 5.63364,
#   'market_cap_change_24h': 199183977,
#   'market_cap_change_percentage_24h': 5.88063,
#   'circulating_supply': 25263013692.0,
#   'total_supply': 30263013692.0,
#   'max_supply': None,
#   'ath': 0.27702,
#   'ath_change_percentage': -48.81575,
#   'ath_date': '2021-02-22T11:33:57.751Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 1069.92839,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:31.244Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'image': 'https://assets.coingecko.com/coins/images/13397/large/Graph_Token.png?1608145566',
#   'current_price': 0.733217,
#   'market_cap': 3442273749,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 7299548432,
#   'total_volume': 192692626,
#   'high_24h': 0.736278,
#   'low_24h': 0.663503,
#   'price_change_24h': 0.056997,
#   'price_change_percentage_24h': 8.42884,
#   'market_cap_change_24h': 322970624,
#   'market_cap_change_percentage_24h': 10.35394,
#   'circulating_supply': 4715735200.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.84,
#   'ath_change_percentage': -74.25921,
#   'ath_date': '2021-02-12T07:28:45.775Z',
#   'atl': 0.103254,
#   'atl_change_percentage': 608.37295,
#   'atl_date': '2020-12-17T21:28:41.332Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:51.587Z'},
#  {'id': 'neo',
#   'symbol': 'neo',
#   'name': 'NEO',
#   'image': 'https://assets.coingecko.com/coins/images/480/large/NEO_512_512.png?1594357361',
#   'current_price': 46.22,
#   'market_cap': 3247054788,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': None,
#   'total_volume': 426069022,
#   'high_24h': 46.78,
#   'low_24h': 43.87,
#   'price_change_24h': 1.52,
#   'price_change_percentage_24h': 3.40041,
#   'market_cap_change_24h': 113720638,
#   'market_cap_change_percentage_24h': 3.62938,
#   'circulating_supply': 70530000.0,
#   'total_supply': 100000000.0,
#   'max_supply': None,
#   'ath': 198.38,
#   'ath_change_percentage': -76.74115,
#   'ath_date': '2018-01-15T00:00:00.000Z',
#   'atl': 0.078349,
#   'atl_change_percentage': 58791.60682,
#   'atl_date': '2016-10-21T00:00:00.000Z',
#   'roi': {'times': 1282.9564399931894,
#    'currency': 'usd',
#    'percentage': 128295.64399931894},
#   'last_updated': '2021-08-10T05:33:52.365Z'},
#  {'id': 'klay-token',
#   'symbol': 'klay',
#   'name': 'Klaytn',
#   'image': 'https://assets.coingecko.com/coins/images/9672/large/CjbT82vP_400x400.jpg?1570548320',
#   'current_price': 1.23,
#   'market_cap': 3081095070,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': None,
#   'total_volume': 60935461,
#   'high_24h': 1.25,
#   'low_24h': 1.19,
#   'price_change_24h': 0.03530344,
#   'price_change_percentage_24h': 2.94326,
#   'market_cap_change_24h': 130235158,
#   'market_cap_change_percentage_24h': 4.41346,
#   'circulating_supply': 2494080827.6,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4.34,
#   'ath_change_percentage': -71.63496,
#   'ath_date': '2021-03-30T03:44:28.828Z',
#   'atl': 0.06044,
#   'atl_change_percentage': 1936.30519,
#   'atl_date': '2020-04-29T08:19:34.574Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:24.740Z'},
#  {'id': 'maker',
#   'symbol': 'mkr',
#   'name': 'Maker',
#   'image': 'https://assets.coingecko.com/coins/images/1364/large/Mark_Maker.png?1585191826',
#   'current_price': 3378.23,
#   'market_cap': 2994076500,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 3340439250,
#   'total_volume': 119254292,
#   'high_24h': 3378.81,
#   'low_24h': 3114.66,
#   'price_change_24h': 219.57,
#   'price_change_percentage_24h': 6.95144,
#   'market_cap_change_24h': 176320123,
#   'market_cap_change_percentage_24h': 6.25747,
#   'circulating_supply': 901310.9472893132,
#   'total_supply': 991328.381954929,
#   'max_supply': 1005577.0,
#   'ath': 6292.31,
#   'ath_change_percentage': -46.63595,
#   'ath_date': '2021-05-03T21:54:29.333Z',
#   'atl': 168.36,
#   'atl_change_percentage': 1894.46545,
#   'atl_date': '2020-03-16T20:52:36.527Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:44.475Z'},
#  {'id': 'amp-token',
#   'symbol': 'amp',
#   'name': 'Amp',
#   'image': 'https://assets.coingecko.com/coins/images/12409/large/amp-200x200.png?1599625397',
#   'current_price': 0.061283,
#   'market_cap': 2933778546,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 6062921003,
#   'total_volume': 41350207,
#   'high_24h': 0.062728,
#   'low_24h': 0.059106,
#   'price_change_24h': 0.00200883,
#   'price_change_percentage_24h': 3.38903,
#   'market_cap_change_24h': 46728595,
#   'market_cap_change_percentage_24h': 1.61856,
#   'circulating_supply': 48013928909.1577,
#   'total_supply': 99226115264.401,
#   'max_supply': 99225164238.50153,
#   'ath': 0.120813,
#   'ath_change_percentage': -49.30966,
#   'ath_date': '2021-06-16T16:03:41.147Z',
#   'atl': 0.00250501,
#   'atl_change_percentage': 2344.7114,
#   'atl_date': '2020-11-04T13:18:12.191Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:25.753Z'},
#  {'id': 'bitcoin-cash-sv',
#   'symbol': 'bsv',
#   'name': 'Bitcoin SV',
#   'image': 'https://assets.coingecko.com/coins/images/6799/large/BSV.png?1558947902',
#   'current_price': 152.44,
#   'market_cap': 2857010381,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': None,
#   'total_volume': 354889093,
#   'high_24h': 155.17,
#   'low_24h': 144.79,
#   'price_change_24h': 6.75,
#   'price_change_percentage_24h': 4.63318,
#   'market_cap_change_24h': 147513948,
#   'market_cap_change_percentage_24h': 5.44433,
#   'circulating_supply': 18810426.644239,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 489.75,
#   'ath_change_percentage': -68.96061,
#   'ath_date': '2021-04-16T17:09:04.630Z',
#   'atl': 42.02,
#   'atl_change_percentage': 261.79296,
#   'atl_date': '2018-11-23T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:32.156Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'AVAX',
#   'name': 'Avalanche',
#   'image': 'https://assets.coingecko.com/coins/images/12559/large/coin-round-red.png?1604021818',
#   'current_price': 16.39,
#   'market_cap': 2834017724,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 11760155592,
#   'total_volume': 126679571,
#   'high_24h': 16.62,
#   'low_24h': 14.59,
#   'price_change_24h': 1.62,
#   'price_change_percentage_24h': 10.95962,
#   'market_cap_change_24h': 306903470,
#   'market_cap_change_percentage_24h': 12.14442,
#   'circulating_supply': 173508993.592496,
#   'total_supply': 377752194.4695483,
#   'max_supply': 720000000.0,
#   'ath': 59.4,
#   'ath_change_percentage': -72.4885,
#   'ath_date': '2021-02-10T22:23:34.616Z',
#   'atl': 2.8,
#   'atl_change_percentage': 483.44903,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:31:30.114Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://assets.coingecko.com/coins/images/8418/large/leo-token.png?1558326215',
#   'current_price': 2.98,
#   'market_cap': 2827339511,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': None,
#   'total_volume': 4976153,
#   'high_24h': 2.99,
#   'low_24h': 2.73,
#   'price_change_24h': 0.103644,
#   'price_change_percentage_24h': 3.60931,
#   'market_cap_change_24h': 95836210,
#   'market_cap_change_percentage_24h': 3.50855,
#   'circulating_supply': 948386503.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 3.95,
#   'ath_change_percentage': -24.4946,
#   'ath_date': '2021-05-14T13:54:31.192Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 272.41354,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:47.324Z'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'image': 'https://assets.coingecko.com/coins/images/976/large/Tezos-logo.png?1547034862',
#   'current_price': 3.26,
#   'market_cap': 2757839730,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': None,
#   'total_volume': 135147544,
#   'high_24h': 3.34,
#   'low_24h': 3.14,
#   'price_change_24h': 0.076027,
#   'price_change_percentage_24h': 2.38584,
#   'market_cap_change_24h': 114719578,
#   'market_cap_change_percentage_24h': 4.34031,
#   'circulating_supply': 840784247.133739,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 8.27,
#   'ath_change_percentage': -60.56823,
#   'ath_date': '2021-05-07T02:09:26.683Z',
#   'atl': 0.350476,
#   'atl_change_percentage': 830.02951,
#   'atl_date': '2018-12-07T00:00:00.000Z',
#   'roi': {'times': 5.941748977284323,
#    'currency': 'usd',
#    'percentage': 594.1748977284324},
#   'last_updated': '2021-08-10T05:33:45.999Z'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'image': 'https://assets.coingecko.com/coins/images/4380/large/download.png?1547039725',
#   'current_price': 0.869279,
#   'market_cap': 2745656701,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 8626796798,
#   'total_volume': 194541096,
#   'high_24h': 0.87802,
#   'low_24h': 0.808752,
#   'price_change_24h': 0.04593968,
#   'price_change_percentage_24h': 5.57967,
#   'market_cap_change_24h': 148491772,
#   'market_cap_change_percentage_24h': 5.71746,
#   'circulating_supply': 3182707052.31814,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 3.56,
#   'ath_change_percentage': -75.66247,
#   'ath_date': '2019-06-20T14:51:19.480Z',
#   'atl': 0.105336,
#   'atl_change_percentage': 722.79667,
#   'atl_date': '2020-03-13T02:20:48.438Z',
#   'roi': {'times': -0.6378002445717095,
#    'currency': 'usd',
#    'percentage': -63.78002445717095},
#   'last_updated': '2021-08-10T05:33:48.324Z'},
#  {'id': 'celsius-degree-token',
#   'symbol': 'cel',
#   'name': 'Celsius Network',
#   'image': 'https://assets.coingecko.com/coins/images/3263/large/CEL_logo.png?1609598753',
#   'current_price': 6.44,
#   'market_cap': 2733734713,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': None,
#   'total_volume': 12053609,
#   'high_24h': 6.56,
#   'low_24h': 6.19,
#   'price_change_24h': 0.199239,
#   'price_change_percentage_24h': 3.19318,
#   'market_cap_change_24h': 100718167,
#   'market_cap_change_percentage_24h': 3.8252,
#   'circulating_supply': 423415980.3475,
#   'total_supply': 695658160.9671,
#   'max_supply': None,
#   'ath': 8.05,
#   'ath_change_percentage': -20.06236,
#   'ath_date': '2021-06-04T00:04:12.584Z',
#   'atl': 0.02620268,
#   'atl_change_percentage': 24449.33314,
#   'atl_date': '2018-12-07T00:00:00.000Z',
#   'roi': {'times': 20.462526267049057,
#    'currency': 'usd',
#    'percentage': 2046.2526267049057},
#   'last_updated': '2021-08-10T05:32:42.208Z'},
#  {'id': 'elrond-erd-2',
#   'symbol': 'egld',
#   'name': 'Elrond',
#   'image': 'https://assets.coingecko.com/coins/images/12335/large/elrond3_360.png?1626341589',
#   'current_price': 135.86,
#   'market_cap': 2602934655,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': None,
#   'total_volume': 96106822,
#   'high_24h': 135.82,
#   'low_24h': 123.12,
#   'price_change_24h': 11.5,
#   'price_change_percentage_24h': 9.24719,
#   'market_cap_change_24h': 223514295,
#   'market_cap_change_percentage_24h': 9.39364,
#   'circulating_supply': 19553455.0,
#   'total_supply': 20397843.0,
#   'max_supply': None,
#   'ath': 243.92,
#   'ath_change_percentage': -44.66664,
#   'ath_date': '2021-04-12T02:24:35.343Z',
#   'atl': 6.51,
#   'atl_change_percentage': 1974.33841,
#   'atl_date': '2020-10-07T01:44:53.554Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:14.419Z'},
#  {'id': 'compound-governance-token',
#   'symbol': 'comp',
#   'name': 'Compound',
#   'image': 'https://assets.coingecko.com/coins/images/10775/large/COMP.png?1592625425',
#   'current_price': 476.68,
#   'market_cap': 2560955798,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 4741769080,
#   'total_volume': 165224306,
#   'high_24h': 486.42,
#   'low_24h': 453.36,
#   'price_change_24h': 15.42,
#   'price_change_percentage_24h': 3.34347,
#   'market_cap_change_24h': 90451203,
#   'market_cap_change_percentage_24h': 3.66124,
#   'circulating_supply': 5400844.610974923,
#   'total_supply': 10000000.0,
#   'max_supply': 10000000.0,
#   'ath': 910.54,
#   'ath_change_percentage': -47.73311,
#   'ath_date': '2021-05-12T02:29:08.794Z',
#   'atl': 61.32,
#   'atl_change_percentage': 676.08829,
#   'atl_date': '2020-06-18T12:54:32.788Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:43.093Z'},
#  {'id': 'iota',
#   'symbol': 'miota',
#   'name': 'IOTA',
#   'image': 'https://assets.coingecko.com/coins/images/692/large/IOTA_Swirl.png?1604238557',
#   'current_price': 0.902987,
#   'market_cap': 2534240694,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': None,
#   'total_volume': 40966019,
#   'high_24h': 0.922317,
#   'low_24h': 0.855455,
#   'price_change_24h': 0.03801992,
#   'price_change_percentage_24h': 4.39553,
#   'market_cap_change_24h': 149333138,
#   'market_cap_change_percentage_24h': 6.26159,
#   'circulating_supply': 2779530283.277761,
#   'total_supply': 2779530283.0,
#   'max_supply': None,
#   'ath': 5.25,
#   'ath_change_percentage': -82.82779,
#   'ath_date': '2017-12-19T00:00:00.000Z',
#   'atl': 0.081637,
#   'atl_change_percentage': 1004.06716,
#   'atl_date': '2020-03-13T02:22:41.168Z',
#   'roi': {'times': 13.746357647624395,
#    'currency': 'btc',
#    'percentage': 1374.6357647624395},
#   'last_updated': '2021-08-10T05:32:29.278Z'},
#  {'id': 'bittorrent-2',
#   'symbol': 'btt',
#   'name': 'BitTorrent',
#   'image': 'https://assets.coingecko.com/coins/images/7595/large/BTT_Token_Graphic.png?1555066995',
#   'current_price': 0.00383673,
#   'market_cap': 2531966848,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': None,
#   'total_volume': 380228221,
#   'high_24h': 0.0039017,
#   'low_24h': 0.00369614,
#   'price_change_24h': 5.731e-05,
#   'price_change_percentage_24h': 1.51648,
#   'market_cap_change_24h': 35428131,
#   'market_cap_change_percentage_24h': 1.41909,
#   'circulating_supply': 659071882049.0,
#   'total_supply': 990000000000.0,
#   'max_supply': None,
#   'ath': 0.01356626,
#   'ath_change_percentage': -71.74424,
#   'ath_date': '2021-04-05T04:09:06.433Z',
#   'atl': 0.00013814,
#   'atl_change_percentage': 2674.84562,
#   'atl_date': '2020-03-13T02:22:57.629Z',
#   'roi': {'times': 30.97277450354424,
#    'currency': 'usd',
#    'percentage': 3097.277450354424},
#   'last_updated': '2021-08-10T05:33:53.375Z'},
#  {'id': 'axie-infinity',
#   'symbol': 'axs',
#   'name': 'Axie Infinity',
#   'image': 'https://assets.coingecko.com/coins/images/13029/large/axie_infinity_logo.png?1604471082',
#   'current_price': 44.81,
#   'market_cap': 2510426328,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 12265924466,
#   'total_volume': 669728271,
#   'high_24h': 45.52,
#   'low_24h': 42.28,
#   'price_change_24h': 1.99,
#   'price_change_percentage_24h': 4.64225,
#   'market_cap_change_24h': 139764414,
#   'market_cap_change_percentage_24h': 5.89559,
#   'circulating_supply': 55260010.0,
#   'total_supply': 270000000.0,
#   'max_supply': 270000000.0,
#   'ath': 52.17,
#   'ath_change_percentage': -13.84429,
#   'ath_date': '2021-07-27T15:05:01.406Z',
#   'atl': 0.123718,
#   'atl_change_percentage': 36233.10011,
#   'atl_date': '2020-11-06T08:05:43.662Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:29.448Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://assets.coingecko.com/coins/images/13442/large/steth_logo.png?1608607546',
#   'current_price': 3111.36,
#   'market_cap': 2336690099,
#   'market_cap_rank': 55,
#   'fully_diluted_valuation': 2336690099,
# ...
#   'market_cap_change_24h': 68320704,
#   'market_cap_change_percentage_24h': 6.39879,
#   'circulating_supply': 12339910544.222,
#   'total_supply': 21000000000.0,
#   'max_supply': None,
#   'ath': 0.255376,
#   'ath_change_percentage': -63.82299,
#   'ath_date': '2021-05-06T17:33:45.940Z',
#   'atl': 0.00239616,
#   'atl_change_percentage': 3755.64288,
#   'atl_date': '2020-03-13T02:22:55.161Z',
#   'roi': {'times': 2.485079634071098,
#    'currency': 'eth',
#    'percentage': 248.5079634071098},
#   'last_updated': '2021-08-10T05:32:43.983Z'},
#  {'id': 'nexo',
#   'symbol': 'nexo',
#   'name': 'NEXO',
#   'image': 'https://assets.coingecko.com/coins/images/3695/large/nexo.png?1548086057',
#   'current_price': 1.98,
#   'market_cap': 1099856744,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 1964029864,
#   'total_volume': 10562896,
#   'high_24h': 2.0,
#   'low_24h': 1.81,
#   'price_change_24h': 0.117862,
#   'price_change_percentage_24h': 6.32771,
#   'market_cap_change_24h': 54258879,
#   'market_cap_change_percentage_24h': 5.18927,
#   'circulating_supply': 560000010.0064,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 4.07,
#   'ath_change_percentage': -51.4533,
#   'ath_date': '2021-05-12T14:37:47.535Z',
#   'atl': 0.04515276,
#   'atl_change_percentage': 4273.74191,
#   'atl_date': '2018-09-13T00:00:00.000Z',
#   'roi': {'times': 18.80494721229063,
#    'currency': 'usd',
#    'percentage': 1880.494721229063},
#   'last_updated': '2021-08-10T05:32:30.186Z'},
#  {'id': 'qtum',
#   'symbol': 'qtum',
#   'name': 'Qtum',
#   'image': 'https://assets.coingecko.com/coins/images/684/large/qtum.png?1547034438',
#   'current_price': 10.56,
#   'market_cap': 1093767078,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': None,
#   'total_volume': 335175428,
#   'high_24h': 11.02,
#   'low_24h': 10.42,
#   'price_change_24h': -0.116263157879,
#   'price_change_percentage_24h': -1.08947,
#   'market_cap_change_24h': -28144191.90994978,
#   'market_cap_change_percentage_24h': -2.50859,
#   'circulating_supply': 103635060.0,
#   'total_supply': 107822406.0,
#   'max_supply': None,
#   'ath': 100.22,
#   'ath_change_percentage': -89.47307,
#   'ath_date': '2018-01-06T00:00:00.000Z',
#   'atl': 0.783142,
#   'atl_change_percentage': 1247.20278,
#   'atl_date': '2020-03-13T02:22:57.149Z',
#   'roi': {'times': 34.1843578967907,
#    'currency': 'usd',
#    'percentage': 3418.43578967907},
#   'last_updated': '2021-08-10T05:33:55.068Z'},
#  {'id': 'bitcoin-cash-abc-2',
#   'symbol': 'bcha',
#   'name': 'Bitcoin Cash ABC',
#   'image': 'https://assets.coingecko.com/coins/images/13120/large/Logo_final-21.png?1624892810',
#   'current_price': 58.04,
#   'market_cap': 1092782352,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': None,
#   'total_volume': 93177276,
#   'high_24h': 60.38,
#   'low_24h': 57.88,
#   'price_change_24h': -2.339382408896,
#   'price_change_percentage_24h': -3.87435,
#   'market_cap_change_24h': -12797539.203139544,
#   'market_cap_change_percentage_24h': -1.15754,
#   'circulating_supply': 18794058.3967894,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 71.38,
#   'ath_change_percentage': -18.76199,
#   'ath_date': '2021-08-06T08:52:10.407Z',
#   'atl': 9.21,
#   'atl_change_percentage': 529.64491,
#   'atl_date': '2020-11-15T18:28:32.658Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:10.668Z'},
#  {'id': 'ravencoin',
#   'symbol': 'rvn',
#   'name': 'Ravencoin',
#   'image': 'https://assets.coingecko.com/coins/images/3412/large/ravencoin.png?1548386057',
#   'current_price': 0.11806,
#   'market_cap': 1073263813,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': None,
#   'total_volume': 334030203,
#   'high_24h': 0.118913,
#   'low_24h': 0.094978,
#   'price_change_24h': 0.02064728,
#   'price_change_percentage_24h': 21.19563,
#   'market_cap_change_24h': 203531432,
#   'market_cap_change_percentage_24h': 23.40162,
#   'circulating_supply': 9394875000.0,
#   'total_supply': 21000000000.0,
#   'max_supply': None,
#   'ath': 0.285218,
#   'ath_change_percentage': -58.76287,
#   'ath_date': '2021-02-20T11:19:07.791Z',
#   'atl': 0.00893232,
#   'atl_change_percentage': 1216.74286,
#   'atl_date': '2020-03-13T02:30:00.004Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:45.835Z'},
#  {'id': 'basic-attention-token',
#   'symbol': 'bat',
#   'name': 'Basic Attention Token',
#   'image': 'https://assets.coingecko.com/coins/images/677/large/basic-attention-token.png?1547034427',
#   'current_price': 0.710905,
#   'market_cap': 1057759734,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 1065543112,
#   'total_volume': 115204835,
#   'high_24h': 0.714998,
#   'low_24h': 0.661173,
#   'price_change_24h': 0.04149541,
#   'price_change_percentage_24h': 6.1988,
#   'market_cap_change_24h': 74810175,
#   'market_cap_change_percentage_24h': 7.61078,
#   'circulating_supply': 1489043083.9673505,
#   'total_supply': 1500000000.0,
#   'max_supply': 1500000000.0,
#   'ath': 1.63,
#   'ath_change_percentage': -56.50691,
#   'ath_date': '2021-04-09T19:03:22.356Z',
#   'atl': 0.072394,
#   'atl_change_percentage': 880.09928,
#   'atl_date': '2017-07-16T00:00:00.000Z',
#   'roi': {'times': 0.4519068718410406,
#    'currency': 'eth',
#    'percentage': 45.190687184104064},
#   'last_updated': '2021-08-10T05:33:47.671Z'},
#  {'id': 'bitclout',
#   'symbol': 'clout',
#   'name': 'BitClout',
#   'image': 'https://assets.coingecko.com/coins/images/16310/large/k-h6Wead_400x400.jpg?1623726134',
#   'current_price': 99.99,
#   'market_cap': 1051273650,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': 1078846340,
#   'total_volume': 1539142,
#   'high_24h': 101.12,
#   'low_24h': 77.51,
#   'price_change_24h': -0.152409687644,
#   'price_change_percentage_24h': -0.1522,
#   'market_cap_change_24h': -1737258.6095627546,
#   'market_cap_change_percentage_24h': -0.16498,
#   'circulating_supply': 10532253.8854,
#   'total_supply': 10808492.6854,
#   'max_supply': 10808492.6854,
#   'ath': 198.68,
#   'ath_change_percentage': -49.64425,
#   'ath_date': '2021-06-19T20:53:25.052Z',
#   'atl': 77.51,
#   'atl_change_percentage': 29.07629,
#   'atl_date': '2021-08-09T23:13:42.318Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:29:54.971Z'},
#  {'id': 'decentraland',
#   'symbol': 'mana',
#   'name': 'Decentraland',
#   'image': 'https://assets.coingecko.com/coins/images/878/large/decentraland-mana.png?1550108745',
#   'current_price': 0.78974,
#   'market_cap': 1043315418,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 1724580712,
#   'total_volume': 177251337,
#   'high_24h': 0.791511,
#   'low_24h': 0.718907,
#   'price_change_24h': 0.058098,
#   'price_change_percentage_24h': 7.94077,
#   'market_cap_change_24h': 98661708,
#   'market_cap_change_percentage_24h': 10.44422,
#   'circulating_supply': 1327372145.9864838,
#   'total_supply': 2194121127.32015,
#   'max_supply': 2194121127.32015,
#   'ath': 1.6,
#   'ath_change_percentage': -50.73289,
#   'ath_date': '2021-05-07T15:54:15.763Z',
#   'atl': 0.00923681,
#   'atl_change_percentage': 8416.11783,
#   'atl_date': '2017-10-31T00:00:00.000Z',
#   'roi': {'times': 38.487022038412405,
#    'currency': 'usd',
#    'percentage': 3848.7022038412406},
#   'last_updated': '2021-08-10T05:33:43.637Z'},
#  {'id': 'telcoin',
#   'symbol': 'tel',
#   'name': 'Telcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1899/large/tel.png?1547036203',
#   'current_price': 0.01825481,
#   'market_cap': 1042382391,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': None,
#   'total_volume': 22649423,
#   'high_24h': 0.01871445,
#   'low_24h': 0.01658129,
#   'price_change_24h': 0.00143418,
#   'price_change_percentage_24h': 8.52629,
#   'market_cap_change_24h': 93732688,
#   'market_cap_change_percentage_24h': 9.88064,
#   'circulating_supply': 56969406904.06,
#   'total_supply': 100000000000.0,
#   'max_supply': None,
#   'ath': 0.064483,
#   'ath_change_percentage': -71.84681,
#   'ath_date': '2021-05-11T00:32:24.043Z',
#   'atl': 6.474e-05,
#   'atl_change_percentage': 27942.92727,
#   'atl_date': '2020-03-13T02:24:47.992Z',
#   'roi': {'times': 17.25480602615646,
#    'currency': 'usd',
#    'percentage': 1725.480602615646},
#   'last_updated': '2021-08-10T05:32:45.471Z'},
#  {'id': 'bitcoin-gold',
#   'symbol': 'btg',
#   'name': 'Bitcoin Gold',
#   'image': 'https://assets.coingecko.com/coins/images/1043/large/bitcoin-gold-logo.png?1547034978',
#   'current_price': 59.12,
#   'market_cap': 1037464376,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': None,
#   'total_volume': 83380941,
#   'high_24h': 60.49,
#   'low_24h': 56.12,
#   'price_change_24h': 2.12,
#   'price_change_percentage_24h': 3.72103,
#   'market_cap_change_24h': 48531579,
#   'market_cap_change_percentage_24h': 4.90747,
#   'circulating_supply': 17513924.0,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 456.25,
#   'ath_change_percentage': -87.04357,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 4.25,
#   'atl_change_percentage': 1289.44499,
#   'atl_date': '2020-03-13T02:22:52.902Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:14.715Z'},
#  {'id': 'harmony',
#   'symbol': 'one',
#   'name': 'Harmony',
#   'image': 'https://assets.coingecko.com/coins/images/4344/large/Y88JAze.png?1565065793',
#   'current_price': 0.094718,
#   'market_cap': 988506355,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': None,
#   'total_volume': 93973842,
#   'high_24h': 0.097269,
#   'low_24h': 0.079233,
#   'price_change_24h': 0.01450529,
#   'price_change_percentage_24h': 18.08363,
#   'market_cap_change_24h': 160840463,
#   'market_cap_change_percentage_24h': 19.43302,
#   'circulating_supply': 10430510382.7931,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.222092,
#   'ath_change_percentage': -58.21785,
#   'ath_date': '2021-03-29T08:19:36.363Z',
#   'atl': 0.00127355,
#   'atl_change_percentage': 7186.30536,
#   'atl_date': '2020-03-13T02:24:14.005Z',
#   'roi': {'times': 28.832295596962386,
#    'currency': 'usd',
#    'percentage': 2883.2295596962385},
#   'last_updated': '2021-08-10T05:30:41.651Z'},
#  {'id': 'bancor',
#   'symbol': 'bnt',
#   'name': 'Bancor Network Token',
#   'image': 'https://assets.coingecko.com/coins/images/736/large/bancor.png?1547034477',
#   'current_price': 3.97,
#   'market_cap': 945695427,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 945695427,
#   'total_volume': 73925305,
#   'high_24h': 4.02,
#   'low_24h': 3.73,
#   'price_change_24h': 0.189329,
#   'price_change_percentage_24h': 5.00902,
#   'market_cap_change_24h': 52415930,
#   'market_cap_change_percentage_24h': 5.86781,
#   'circulating_supply': 238255597.996018,
#   'total_supply': 238058767.776055,
#   'max_supply': 238058767.776055,
#   'ath': 10.72,
#   'ath_change_percentage': -63.00493,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.120935,
#   'atl_change_percentage': 3177.93881,
#   'atl_date': '2020-03-13T02:29:21.245Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:33:46.793Z'},
#  {'id': 'paxos-standard',
#   'symbol': 'pax',
#   'name': 'Paxos Standard',
#   'image': 'https://assets.coingecko.com/coins/images/6013/large/paxos_standard.png?1548386291',
#   'current_price': 1.0,
#   'market_cap': 927056300,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': None,
#   'total_volume': 76079515,
#   'high_24h': 1.01,
#   'low_24h': 0.988987,
#   'price_change_24h': 0.00050474,
#   'price_change_percentage_24h': 0.05045,
#   'market_cap_change_24h': -841971.9186654091,
#   'market_cap_change_percentage_24h': -0.09074,
#   'circulating_supply': 929602919.06,
#   'total_supply': 929602919.06,
#   'max_supply': None,
#   'ath': 1.13,
#   'ath_change_percentage': -11.19784,
#   'ath_date': '2018-10-15T07:09:12.459Z',
#   'atl': 0.863529,
#   'atl_change_percentage': 15.96595,
#   'atl_date': '2021-05-19T13:14:42.046Z',
#   'roi': {'times': 0.000953606792888,
#    'currency': 'usd',
#    'percentage': 0.0953606792888},
#   'last_updated': '2021-08-10T05:33:15.424Z'},
#  {'id': 'ethos',
#   'symbol': 'vgx',
#   'name': 'Voyager Token',
#   'image': 'https://assets.coingecko.com/coins/images/794/large/Voyager-vgx.png?1575693595',
#   'current_price': 4.03,
#   'market_cap': 915200798,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': None,
#   'total_volume': 13101910,
#   'high_24h': 4.25,
#   'low_24h': 3.4,
#   'price_change_24h': 0.564681,
#   'price_change_percentage_24h': 16.27715,
#   'market_cap_change_24h': 144049354,
#   'market_cap_change_percentage_24h': 18.67977,
#   'circulating_supply': 222295208.238453,
#   'total_supply': 222295208.238453,
#   'max_supply': None,
#   'ath': 12.47,
#   'ath_change_percentage': -67.30128,
#   'ath_date': '2018-01-06T00:00:00.000Z',
#   'atl': 0.01689847,
#   'atl_change_percentage': 24037.9303,
#   'atl_date': '2019-12-26T22:10:32.136Z',
#   'roi': {'times': 133.46146652495906,
#    'currency': 'usd',
#    'percentage': 13346.146652495907},
#   'last_updated': '2021-08-10T05:32:14.794Z'},
#  {'id': 'kucoin-shares',
#   'symbol': 'kcs',
#   'name': 'KuCoin Token',
#   'image': 'https://assets.coingecko.com/coins/images/1047/large/sa9z79.png?1610678720',
#   'current_price': 10.74,
#   'market_cap': 843142346,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': None,
#   'total_volume': 14334529,
#   'high_24h': 10.86,
#   'low_24h': 10.35,
#   'price_change_24h': 0.304323,
#   'price_change_percentage_24h': 2.91735,
#   'market_cap_change_24h': 44090968,
#   'market_cap_change_percentage_24h': 5.51791,
#   'circulating_supply': 78068031.0,
#   'total_supply': 168068031.0,
#   'max_supply': None,
#   'ath': 20.17,
#   'ath_change_percentage': -46.90231,
#   'ath_date': '2018-01-10T00:00:00.000Z',
#   'atl': 0.342863,
#   'atl_change_percentage': 3023.2363,
#   'atl_date': '2019-02-07T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:30:33.732Z'},
#  {'id': 'xsushi',
#   'symbol': 'xsushi',
#   'name': 'xSUSHI',
#   'image': 'https://assets.coingecko.com/coins/images/13725/large/xsushi.png?1612538526',
#   'current_price': 11.98,
#   'market_cap': 839059751,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': None,
#   'total_volume': 2514794,
#   'high_24h': 11.98,
#   'low_24h': 10.84,
#   'price_change_24h': 1.07,
#   'price_change_percentage_24h': 9.78145,
#   'market_cap_change_24h': 63843549,
#   'market_cap_change_percentage_24h': 8.23558,
#   'circulating_supply': 71200545.6594487,
#   'total_supply': 71203506.9881816,
#   'max_supply': None,
#   'ath': 26.33,
#   'ath_change_percentage': -54.50572,
#   'ath_date': '2021-03-13T23:01:02.266Z',
#   'atl': 6.04,
#   'atl_change_percentage': 98.28601,
#   'atl_date': '2021-01-22T01:04:22.350Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:32:32.938Z'},
#  {'id': 'nxm',
#   'symbol': 'nxm',
#   'name': 'Nexus Mutual',
#   'image': 'https://assets.coingecko.com/coins/images/11810/large/nexus-mutual.jpg?1594547726',
#   'current_price': 119.25,
#   'market_cap': 826534268,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': 826534268,
#   'total_volume': 77204,
#   'high_24h': 120.89,
#   'low_24h': 111.48,
#   'price_change_24h': 6.29,
#   'price_change_percentage_24h': 5.5659,
#   'market_cap_change_24h': 59416433,
#   'market_cap_change_percentage_24h': 7.74541,
#   'circulating_supply': 6906145.01964233,
#   'total_supply': 6906146.01014368,
#   'max_supply': 6906146.01014368,
#   'ath': 165.38,
#   'ath_change_percentage': -27.88828,
#   'ath_date': '2021-05-12T14:56:42.518Z',
#   'atl': 6.96,
#   'atl_change_percentage': 1612.71582,
#   'atl_date': '2020-07-22T19:54:06.406Z',
#   'roi': None,
#   'last_updated': '2021-08-10T05:17:58.318Z'},
#  {'id': 'siacoin',
#   'symbol': 'sc',
#   'name': 'Siacoin',
#   'image': 'https://assets.coingecko.com/coins/images/289/large/siacoin.png?1548386465',
#   'current_price': 0.01690396,
#   'market_cap': 823415030,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': None,
#   'total_volume': 59626948,
#   'high_24h': 0.01713498,
#   'low_24h': 0.01590259,
#   'price_change_24h': 0.00076204,
#   'price_change_percentage_24h': 4.72089,
#   'market_cap_change_24h': 49947911,
#   'market_cap_change_percentage_24h': 6.45766,
#   'circulating_supply': 48567495000.0,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.092868,
#   'ath_change_percentage': -81.83453,
#   'ath_date': '2018-01-06T00:00:00.000Z',
#   'atl': 1.262e-05,
#   'atl_change_percentage': 133562.50288,
#   'atl_date': '2015-12-28T00:00:00.000Z',
#   'roi': {'times': 0.7614785997186938,
#    'currency': 'btc',
#    'percentage': 76.14785997186938},
#   'last_updated': '2021-08-10T05:32:26.188Z'}]
