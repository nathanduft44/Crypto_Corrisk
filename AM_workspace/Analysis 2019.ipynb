# %%
# Import the required libraries and dependencies
import numpy as np
from pathlib import Path
import pandas as pd
# %matplotlib inline

# %%
# Import the data by reading in the CSV file and setting the DatetimeIndex
# Review the first 5 rows of the DataFrame
csv_path = Path("../MB_folder/2019_data.csv")
crypto_2019_data = pd.read_csv(csv_path,parse_dates=True,index_col=['btc_start_date','eth_start_date','ltc_start_date','ada_start_date','xlm_start_date','xrp_start_date','lisk_start_date','waves_start_date','zec_start_date','sc_start_date','usdt_start_date','dash_start_date'], infer_datetime_format=True)
crypto_2019_data
# Out:
#                                                                                                                                                                                                                                                                                                                               Unnamed: 0  \
# btc_start_date            eth_start_date            ltc_start_date            ada_start_date            xlm_start_date            xrp_start_date            lisk_start_date           waves_start_date          zec_start_date            sc_start_date             usdt_start_date           dash_start_date
# NaN                       NaN                       NaN                       NaN                       NaN                       NaN                       2019-11-01 00:00:00+00:00 2019-10-01 00:00:00+00:00 NaN                       2019-10-01 00:00:00+00:00 NaN                       NaN                                      0
# ...

# %%
monthly_returns = crypto_2019_data['price_close'].pct_change().dropna()
monthly_returns.head()
# Out:
# btc_start_date             eth_start_date             ltc_start_date             ada_start_date  xlm_start_date  xrp_start_date  lisk_start_date  waves_start_date  zec_start_date             sc_start_date  usdt_start_date  dash_start_date
# 2019-02-01 00:00:00+00:00  2019-11-01 00:00:00+00:00  2019-03-01 00:00:00+00:00  NaN             NaN             NaN             NaN              NaN               2019-12-01 00:00:00+00:00  NaN            NaN              NaN                0.112653
# 2019-03-01 00:00:00+00:00  2019-12-01 00:00:00+00:00  2019-04-01 00:00:00+00:00  NaN             NaN             NaN             NaN              NaN               NaN                        NaN            NaN              NaN                0.079474
# 2019-04-01 00:00:00+00:00  NaN                        2019-05-01 00:00:00+00:00  NaN             NaN             NaN             NaN              NaN               NaN                        NaN            NaN              NaN                0.287410
# ...
