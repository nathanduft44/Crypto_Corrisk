# %%
# GOAL: HAVE EACH ANALYSIS SECTION COMPUTE A STANDARD SET OF CALCULATIONS FOR RISK METRICS AND CORRELATION
"""
For now, we keep it simple. If we need to expand, we can. 
We are taking what we need to in order to understand how each basket of currencies 
is correlated to the market proxy (bitcoin)
"""
# Out:
# '\nFor now, we keep it simple. If we need to expand, we can. \nWe are taking what we need to in order to understand how each basket of currencies \nis correlated to the market proxy (bitcoin)\n'

# %%
# STEP 1: IMPORT DEPENDENCIES

from pathlib import Path

import pandas as pd

import numpy as np




import seaborn as sns

# %matplotlib inline


import hvplot.pandas

# %% [markdown]
# ## Data Collection / Prep

# %%
# STEP 2: IMPORT DATA AS DATAFRAME
"""
Determnine if we are reading csv data, running individual api calls, or querying an in-house database
"""

#reading in csv data
df_2020 = pd.read_csv(
    Path('data/2020_sheet.csv'),
)

# display dataframe
df_2020
# Out:
#     Unnamed: 0                btc_start_date  price_open  price_close_BTC  \
# 0            1  2020-01-01T00:00:00.0000000Z      7168.3           9339.3
# 1            2  2020-02-01T00:00:00.0000000Z      9337.1           8529.1
# 2            3  2020-03-01T00:00:00.0000000Z      8526.1           6422.1
# 3            4  2020-04-01T00:00:00.0000000Z      6422.2           8629.6
# 4            5  2020-05-01T00:00:00.0000000Z      8628.3           9447.4
# 5            6  2020-06-01T00:00:00.0000000Z      9447.9           9133.9
# 6            7  2020-07-01T00:00:00.0000000Z      9135.0          11356.2
# 7            8  2020-08-01T00:00:00.0000000Z     11356.1          11656.9
# 8            9  2020-09-01T00:00:00.0000000Z     11657.2          10774.9
# 9           10  2020-10-01T00:00:00.0000000Z     10774.9          13809.1
# 10          11  2020-11-01T00:00:00.0000000Z     13799.0          19708.1
# 11          12  2020-12-01T00:00:00.0000000Z     19706.5          28959.2
#
#     volume_traded                eth_start_date  price_open.1  \
# 0     182284.0527  2020-01-01T00:00:00.0000000Z        128.66
# 1     129239.4747  2020-02-01T00:00:00.0000000Z        179.68
# 2     374848.4202  2020-03-01T00:00:00.0000000Z        217.31
# 3     493231.2333  2020-04-01T00:00:00.0000000Z        133.02
# 4     273682.8022  2020-05-01T00:00:00.0000000Z        206.16
# 5     159149.8859  2020-06-01T00:00:00.0000000Z        231.52
# 6     119522.5584  2020-07-01T00:00:00.0000000Z        225.61
# 7     132919.9780  2020-08-01T00:00:00.0000000Z        346.90
# 8     117605.7608  2020-09-01T00:00:00.0000000Z        434.00
# 9     126881.7274  2020-10-01T00:00:00.0000000Z        359.70
# 10    218391.8895  2020-11-01T00:00:00.0000000Z        386.62
# 11    220494.0010  2020-12-01T00:00:00.0000000Z        616.84
#
#     price_close_ETH  volume_traded.1                ltc_start_date  ...  \
# 0            179.68      1754990.188  2020-01-01T00:00:00.0000000Z  ...
# 1            217.78      2548585.871  2020-02-01T00:00:00.0000000Z  ...
# 2            133.10      4168217.664  2020-03-01T00:00:00.0000000Z  ...
# 3            206.20      4415679.466  2020-04-01T00:00:00.0000000Z  ...
# 4            231.76      1904909.998  2020-05-01T00:00:00.0000000Z  ...
# 5            225.68      1478852.515  2020-06-01T00:00:00.0000000Z  ...
# 6            347.00      1755724.521  2020-07-01T00:00:00.0000000Z  ...
# 7            433.98      2404929.375  2020-08-01T00:00:00.0000000Z  ...
# 8            359.69      2639400.990  2020-09-01T00:00:00.0000000Z  ...
# 9            386.81      1371747.913  2020-10-01T00:00:00.0000000Z  ...
# 10           616.65      2777676.584  2020-11-01T00:00:00.0000000Z  ...
# 11           737.45      2574697.617  2020-12-01T00:00:00.0000000Z  ...
#
#     price_close_SC  volume_traded.10               usdt_start_date  \
# 0          0.00160      1.209589e+08  2020-01-01T00:00:00.0000000Z
# 1          0.00227      4.236297e+08  2020-02-01T00:00:00.0000000Z
# 2          0.00128      4.123741e+08  2020-03-01T00:00:00.0000000Z
# 3          0.00205      3.445902e+08  2020-04-01T00:00:00.0000000Z
# 4          0.00235      4.944967e+08  2020-05-01T00:00:00.0000000Z
# 5          0.00281      9.267979e+08  2020-06-01T00:00:00.0000000Z
# 6          0.00305      8.621860e+08  2020-07-01T00:00:00.0000000Z
# 7          0.00458      1.128243e+09  2020-08-01T00:00:00.0000000Z
# 8          0.00308      5.518485e+08  2020-09-01T00:00:00.0000000Z
# 9          0.00247      3.854770e+08  2020-10-01T00:00:00.0000000Z
# 10         0.00338      8.269231e+08  2020-11-01T00:00:00.0000000Z
# 11         0.00312      9.253945e+08  2020-12-01T00:00:00.0000000Z
#
#    price_open.11  price_close_USDT  volume_traded.11  \
# 0         0.9962            0.9983      5.839821e+07
# 1         0.9983            1.0002      7.386873e+07
# 2         1.0002            1.0017      1.340408e+08
# 3         1.0018            1.0005      2.470204e+08
# 4         1.0003            0.9994      2.094059e+08
# 5         0.9994            0.9998      1.724823e+08
# 6         0.9998            1.0015      1.899132e+08
# 7         1.0014            1.0002      3.606419e+08
# 8         1.0002            1.0000      4.290422e+08
# 9         0.9999            1.0009      3.864529e+08
# 10        1.0009            1.0005      7.230758e+08
# 11        1.0007            1.0010      1.368381e+09
#
#                  dash_start_date price_open.12  price_close_DASH  \
# 0   2020-01-01T00:00:00.0000000Z        40.855           115.961
# 1   2020-02-01T00:00:00.0000000Z       115.514            85.254
# 2   2020-03-01T00:00:00.0000000Z        85.328            64.946
# 3   2020-04-01T00:00:00.0000000Z        64.978            80.817
# 4   2020-05-01T00:00:00.0000000Z        81.300            76.331
# 5   2020-06-01T00:00:00.0000000Z        76.093            68.160
# 6   2020-07-01T00:00:00.0000000Z        67.767            82.629
# 7   2020-08-01T00:00:00.0000000Z        82.725            86.271
# 8   2020-09-01T00:00:00.0000000Z        86.041            69.126
# 9   2020-10-01T00:00:00.0000000Z        69.140            70.231
# 10  2020-11-01T00:00:00.0000000Z        70.395           113.197
# 11  2020-12-01T00:00:00.0000000Z       112.833            99.531
#
#     volume_traded.12
# 0       257263.21400
# 1       101856.82900
# 2       161380.67090
# 3        88228.89156
# 4        57169.60406
# 5        42567.56452
# 6        66764.51436
# 7       162348.71920
# 8        60058.27898
# 9        65521.67667
# 10      199658.44390
# 11      193976.03900
#
# [12 rows x 53 columns]

# %%
# review column names
df_2020.columns
# Out:
# Index(['Unnamed: 0', 'btc_start_date', 'price_open', 'price_close_BTC',
#        'volume_traded', 'eth_start_date', 'price_open.1', 'price_close_ETH',
#        'volume_traded.1', 'ltc_start_date', 'price_open.2', 'price_close_ITC',
#        'volume_traded.2', 'ada_start_date', 'price_open.3', 'price_close_ADA',
#        'volume_traded.3', 'doge_start_date', 'price_open.4',
#        'price_close_DOGE', 'volume_traded.4', 'xlm_start_date', 'price_open.5',
#        'price_close_XLM', 'volume_traded.5', 'xrp_start_date', 'price_open.6',
#        'price_close_XRP', 'volume_traded.6', 'lisk_start_date', 'price_open.7',
#        'price_close_LISK', 'volume_traded.7', 'waves_start_date',
#        'price_open.8', 'price_close_WAVES', 'volume_traded.8',
#        'zec_start_date', 'price_open.9', 'price_close_ZEC', 'volume_traded.9',
#        'sc_start_date', 'price_open.10', 'price_close_SC', 'volume_traded.10',
#        'usdt_start_date', 'price_open.11', 'price_close_USDT',
#        'volume_traded.11', 'dash_start_date', 'price_open.12',
#        'price_close_DASH', 'volume_traded.12'],
#       dtype='object')

# %%
# finalizing working df
final_2020_df = pd.DataFrame()
final_2020_df['BTC_Monthly_Close'] = df_2020['price_close_BTC']
final_2020_df['ETH_Monthly_Close'] = df_2020['price_close_ETH']
final_2020_df['ITC_Monthly_Close'] = df_2020['price_close_ITC']
final_2020_df['ADA_Monthly_Close'] = df_2020['price_close_ADA']
final_2020_df['DOGE_Monthly_Close'] = df_2020['price_close_DOGE']
final_2020_df['XLM_Monthly_Close'] = df_2020['price_close_XLM']
final_2020_df['XRP_Monthly_Close'] = df_2020['price_close_XRP']
final_2020_df['LISK_Monthly_Close'] = df_2020['price_close_LISK']
final_2020_df['ZEC_Monthly_Close'] = df_2020['price_close_ZEC']
final_2020_df['SC_Monthly_Close'] = df_2020['price_close_SC']
final_2020_df['USDT_Monthly_Close'] = df_2020['price_close_USDT']
final_2020_df['DASH_Monthly_Close'] = df_2020['price_close_DASH']


# display df
final_2020_df
# Out:
#     BTC_Monthly_Close  ETH_Monthly_Close  ITC_Monthly_Close  \
# 0              9339.3             179.68              67.76
# 1              8529.1             217.78              58.13
# 2              6422.1             133.10              39.25
# 3              8629.6             206.20              46.37
# 4              9447.4             231.76              45.59
# 5              9133.9             225.68              41.25
# 6             11356.2             347.00              58.29
# 7             11656.9             433.98              60.97
# 8             10774.9             359.69              46.24
# 9             13809.1             386.81              55.82
# 10            19708.1             616.65              87.67
# 11            28959.2             737.45             124.55
#
#     ADA_Monthly_Close  DOGE_Monthly_Close  XLM_Monthly_Close  \
# 0            0.053794            0.002364           0.060831
# 1            0.047284            0.002213           0.056963
# 2            0.030575            0.001790           0.040939
# 3            0.047481            0.002337           0.067277
# 4            0.074002            0.002538           0.070787
# 5            0.083837            0.002303           0.066922
# 6            0.140104            0.003221           0.096714
# 7            0.122566            0.003227           0.096914
# 8            0.101360            0.002628           0.074600
# 9            0.093183            0.002575           0.077742
# 10           0.172279            0.003545           0.203011
# 11           0.181689            0.004684           0.127627
#
#     XRP_Monthly_Close  LISK_Monthly_Close  ZEC_Monthly_Close  \
# 0             0.23890            1.149000              66.20
# 1             0.22883            1.281456              49.00
# 2             0.17374            0.977245              30.93
# 3             0.21178            1.218623              44.61
# 4             0.20239            1.197980              51.77
# 5             0.17538            1.145737              51.51
# 6             0.26013            1.280154              74.36
# 7             0.28132            1.799000              78.72
# 8             0.24184            1.196873              63.94
# 9             0.23999            1.052737              58.12
# 10            0.66415            1.328984              78.96
# 11            0.21950            1.146250              63.89
#
#     SC_Monthly_Close  USDT_Monthly_Close  DASH_Monthly_Close
# 0            0.00160              0.9983             115.961
# 1            0.00227              1.0002              85.254
# 2            0.00128              1.0017              64.946
# 3            0.00205              1.0005              80.817
# 4            0.00235              0.9994              76.331
# 5            0.00281              0.9998              68.160
# 6            0.00305              1.0015              82.629
# 7            0.00458              1.0002              86.271
# 8            0.00308              1.0000              69.126
# 9            0.00247              1.0009              70.231
# 10           0.00338              1.0005             113.197
# 11           0.00312              1.0010              99.531

# %%
# STEP 3: CALCULATE Monthly RETURNS FOR EACH CURRENCY IN Designated Time range from  DATAFRAME, DROP NULL VALUES
"""

Will need: .pct_change().dropna(inplace = True)

"""

# amking dataframe for calcs
monthly_2020_returns = pd.DataFrame()

# calculating monthly returns on dataframe


monthly_2020_returns['BTC'] = final_2020_df['BTC_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['ETH']= final_2020_df['ETH_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['ITC'] = final_2020_df['ITC_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['ADA'] = final_2020_df['ADA_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['DOGE'] = final_2020_df['DOGE_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['XLM'] = final_2020_df['XLM_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['XRP'] = final_2020_df['XRP_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['LISK'] = final_2020_df['LISK_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['ZEC'] = final_2020_df['ZEC_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['SC'] = final_2020_df['SC_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['USDT'] = final_2020_df['USDT_Monthly_Close'].pct_change().dropna()
monthly_2020_returns['DASH'] = final_2020_df['DASH_Monthly_Close'].pct_change().dropna()

# setting time column for monthly returns data frame
monthly_2020_returns['date'] = df_2020['btc_start_date']

# setting time as index
monthly_2020_returns.set_index('date')
# Out:
#                                    BTC       ETH       ITC       ADA  \
# date
# 2020-02-01T00:00:00.0000000Z -0.086752  0.212044 -0.142119 -0.121017
# 2020-03-01T00:00:00.0000000Z -0.247037 -0.388833 -0.324789 -0.353375
# 2020-04-01T00:00:00.0000000Z  0.343735  0.549211  0.181401  0.552935
# 2020-05-01T00:00:00.0000000Z  0.094767  0.123957 -0.016821  0.558560
# 2020-06-01T00:00:00.0000000Z -0.033184 -0.026234 -0.095196  0.132902
# 2020-07-01T00:00:00.0000000Z  0.243302  0.537575  0.413091  0.671148
# 2020-08-01T00:00:00.0000000Z  0.026479  0.250663  0.045977 -0.125178
# 2020-09-01T00:00:00.0000000Z -0.075663 -0.171183 -0.241594 -0.173017
# 2020-10-01T00:00:00.0000000Z  0.281599  0.075398  0.207180 -0.080673
# 2020-11-01T00:00:00.0000000Z  0.427182  0.594194  0.570584  0.848824
# 2020-12-01T00:00:00.0000000Z  0.469406  0.195897  0.420668  0.054621
#
#                                   DOGE       XLM       XRP      LISK  \
# date
# 2020-02-01T00:00:00.0000000Z -0.063589 -0.063586 -0.042152  0.115279
# 2020-03-01T00:00:00.0000000Z -0.191253 -0.281305 -0.240746 -0.237395
# 2020-04-01T00:00:00.0000000Z  0.305810  0.643347  0.218948  0.246998
# 2020-05-01T00:00:00.0000000Z  0.085736  0.052172 -0.044338 -0.016940
# 2020-06-01T00:00:00.0000000Z -0.092560 -0.054600 -0.133455 -0.043609
# 2020-07-01T00:00:00.0000000Z  0.398845  0.445175  0.483236  0.117319
# 2020-08-01T00:00:00.0000000Z  0.001676  0.002068  0.081459  0.405300
# 2020-09-01T00:00:00.0000000Z -0.185602 -0.230245 -0.140338 -0.334701
# 2020-10-01T00:00:00.0000000Z -0.020054  0.042118 -0.007650 -0.120427
# 2020-11-01T00:00:00.0000000Z  0.376592  1.611343  1.767407  0.262408
# 2020-12-01T00:00:00.0000000Z  0.321382 -0.371330 -0.669502 -0.137499
#
#                                    ZEC        SC      USDT      DASH
# date
# 2020-02-01T00:00:00.0000000Z -0.259819  0.418750  0.001903 -0.264805
# 2020-03-01T00:00:00.0000000Z -0.368776 -0.436123  0.001500 -0.238206
# 2020-04-01T00:00:00.0000000Z  0.442289  0.601562 -0.001198  0.244372
# 2020-05-01T00:00:00.0000000Z  0.160502  0.146341 -0.001099 -0.055508
# 2020-06-01T00:00:00.0000000Z -0.005022  0.195745  0.000400 -0.107047
# 2020-07-01T00:00:00.0000000Z  0.443603  0.085409  0.001700  0.212280
# 2020-08-01T00:00:00.0000000Z  0.058634  0.501639 -0.001298  0.044077
# 2020-09-01T00:00:00.0000000Z -0.187754 -0.327511 -0.000200 -0.198734
# 2020-10-01T00:00:00.0000000Z -0.091023 -0.198052  0.000900  0.015985
# 2020-11-01T00:00:00.0000000Z  0.358568  0.368421 -0.000400  0.611781
# 2020-12-01T00:00:00.0000000Z -0.190856 -0.076923  0.000500 -0.120728

# %%
# STEP 4: CALCULATE VARIANCE OF BITCOIN FOR DATAFRAME
"""

Will need: monthly_returns.var()

"""
# assign to market variance value
market_var = final_2020_df['BTC_Monthly_Close'].var()
market_var
# Out:
# 38862067.28696969

# %%
# STEP 5: CALCULATE COVARIANCE OF EACH CURRENCY RELATIVE TO BITCOIN
"""
Use monthly returns of currency and monthly returns of bitcoin as market proxy

"""
# testing against market to make sure calc is working properly
market_cov = final_2020_df['BTC_Monthly_Close'].cov(final_2020_df['BTC_Monthly_Close'])
market_cov
# Out:
# 38862067.28696969

# %%
# STEP 5: CALCULATE COVARIANCE OF EACH CURRENCY RELATIVE TO BITCOIN
# there's definitely a more efficient way to do this
eth_cov = monthly_2020_returns['ETH'].cov(monthly_2020_returns['BTC'])
itc_cov = monthly_2020_returns['ITC'].cov(monthly_2020_returns['BTC'])
ada_cov = monthly_2020_returns['ADA'].cov(monthly_2020_returns['BTC'])
doge_cov = monthly_2020_returns['DOGE'].cov(monthly_2020_returns['BTC'])
xlm_cov = monthly_2020_returns['XLM'].cov(monthly_2020_returns['BTC'])
xrp_cov = monthly_2020_returns['XRP'].cov(monthly_2020_returns['BTC'])
lisk_cov = monthly_2020_returns['LISK'].cov(monthly_2020_returns['BTC'])
zec_cov = monthly_2020_returns['ZEC'].cov(monthly_2020_returns['BTC'])
sc_cov = monthly_2020_returns['SC'].cov(monthly_2020_returns['BTC'])
usdt_cov = monthly_2020_returns['USDT'].cov(monthly_2020_returns['BTC'])
dash_cov = monthly_2020_returns['DASH'].cov(monthly_2020_returns['BTC'])

# %%
# STEP 6: CALCULATE BETA OF EACH CURRENCY Relative to Bitcoin

"""
beta = covariance of asset to market / variance of market

use previous calculations for market variance and covariance of assets
"""


btc_beta = market_cov / market_var
eth_beta = eth_cov / market_var
itc_beta = itc_cov / market_var
ada_beta = ada_cov / market_var
doge_beta = doge_cov / market_var
xlm_beta = xlm_cov / market_var
xrp_beta = xrp_cov / market_var
lisk_beta = lisk_cov / market_var
zec_beta = zec_cov / market_var
sc_beta = sc_cov / market_var
usdt_beta = usdt_cov / market_var
dash_beta = dash_cov / market_var

# %%
# making list for convenience
Beta_list = [btc_beta, eth_beta, itc_beta, ada_beta, doge_beta, xlm_beta, xrp_beta, lisk_beta, zec_beta, sc_beta, usdt_beta, dash_beta]

Beta_list
# Out:
# [1.0,
#  1.3899287344248775e-09,
#  1.6529352523390184e-09,
#  1.5875551476435363e-09,
#  1.1921735068458976e-09,
#  1.85002665792659e-09,
#  1.3907466327638725e-09,
#  4.578543158735566e-10,
#  1.0174215366167833e-09,
#  6.227064926681269e-10,
#  -1.823257263305262e-12,
#  1.0866715750317962e-09]

# %% [markdown]
# ## Correlation / Spread

# %%
# Display Correlation Heatmap With Seaborn

"""
NEW CELL to check monthly returns are displayed with pct_change already applied
- Take dataframe of daily returns from step 3 (pct_change drop na already applied)

NEW CELL to check correlation dataframe
- correlation = monthly_returns_dataframe.corr()

NEW CELL to display heatmap
- sns.heatmap(correlation)


"""

correlation = monthly_2020_returns.corr()
# sns.heatmap(correlation)

# %%
# a better heatmap function
correlation.hvplot.heatmap()
# Out:
# :HeatMap   [columns,index]   (value)

# %%
monthly_2020_returns.hvplot.box(title = "2020: Spread of Monthly Returns", figsize = (30, 10), rot = 45,  box_fill_color = 'cyan', outlier_color = 'red')
# Out:
# :BoxWhisker   [Variable]   (value)

# %%
# lazy way of compiling summary data
summary_data = monthly_2020_returns.describe()

# basically all this is just to flip charts to make input of the beta series more convenient
summary_data = summary_data.T
summary_data['beta'] = Beta_list
summary_data = summary_data.T

# %%
summary_data
# Out:
#              BTC           ETH           ITC           ADA          DOGE  \
# count  11.000000  1.100000e+01  1.100000e+01  1.100000e+01  1.100000e+01
# mean    0.131258  1.775172e-01  9.258012e-02  1.787027e-01  8.518029e-02
# std     0.235589  3.074822e-01  2.915876e-01  4.061608e-01  2.256735e-01
# min    -0.247037 -3.888328e-01 -3.247893e-01 -3.533753e-01 -1.912529e-01
# 25%    -0.054424  2.458211e-02 -1.186578e-01 -1.230978e-01 -7.807496e-02
# 50%     0.094767  1.958972e-01  4.597701e-02  5.462070e-02  1.676290e-03
# 75%     0.312667  3.941191e-01  3.101354e-01  5.557478e-01  3.135961e-01
# max     0.469406  5.941935e-01  5.705840e-01  8.488244e-01  3.988449e-01
# beta    1.000000  1.389929e-09  1.652935e-09  1.587555e-09  1.192174e-09
#
#                 XLM           XRP          LISK           ZEC            SC  \
# count  1.100000e+01  1.100000e+01  1.100000e+01  1.100000e+01  1.100000e+01
# mean   1.631960e-01  1.157153e-01  2.333949e-02  3.275882e-02  1.162963e-01
# std    5.654286e-01  6.174161e-01  2.278538e-01  2.866807e-01  3.443062e-01
# min   -3.713296e-01 -6.695024e-01 -3.347009e-01 -3.687755e-01 -4.361233e-01
# 25%   -1.469157e-01 -1.368968e-01 -1.289631e-01 -1.893051e-01 -1.374875e-01
# 50%    2.067953e-03 -4.215153e-02 -1.693961e-02 -5.022214e-03  1.463415e-01
# 75%    2.486737e-01  1.502036e-01  1.821588e-01  2.595353e-01  3.935855e-01
# max    1.611343e+00  1.767407e+00  4.052997e-01  4.436032e-01  6.015625e-01
# beta   1.850027e-09  1.390747e-09  4.578543e-10  1.017422e-09  6.227065e-10
#
#                USDT          DASH
# count  1.100000e+01  1.100000e+01
# mean   2.461999e-04  1.304254e-02
# std    1.176618e-03  2.597803e-01
# min   -1.298053e-03 -2.648045e-01
# 25%   -7.495453e-04 -1.597309e-01
# 50%    4.002401e-04 -5.550812e-02
# 75%    1.199850e-03  1.281782e-01
# max    1.903236e-03  6.117811e-01
# beta  -1.823257e-12  1.086672e-09

# %% [markdown]
# ## Standard Deviation

# %%
mean_series = summary_data.loc['mean'].sort_values()
mean_series.hvplot.bar(rot = 45, title = "2020 Bar: Average Monthly Returns by Percentage", fill_color = 'cyan', hover_color = 'black', xlabel = 'Cryptocurrencies', ylabel = 'percentage change')
# Out:
# :Bars   [index]   (mean)

# %%
mean_series = summary_data.loc['mean'].sort_values()
mean_series.hvplot.heatmap(title = "2020 Heatmap: Average Monthly Returns by Percentage", fill_color = 'cyan', hover_color = 'orange')
# Out:
# :HeatMap   [columns,index]   (value)

# %%
# bar chart of standard deviations of top 12 cryptocurrencies




std_dev_series = summary_data.loc['std'].sort_values()
std_dev_series.hvplot.bar(
    rot = 45, 
    title = "2020 Bar: Standard Deviation of Selected Cryptocurrencies", 
    fill_color = 'cyan', hover_color = 'black', 
    xlabel = 'Cryptocurrencies', 
    ylabel = 'Standard Deviation')
# Out:
# :Bars   [index]   (std)

# %%
# bar chart of standard deviations of top 12 cryptocurrencies
std_dev_series = summary_data.loc['std'].sort_values()
std_dev_series.hvplot.heatmap(
    title = "2020 Heatmap: Standard Deviation of Selected Cryptocurrencies", 
    fill_color = 'cyan', hover_color = 'orange', ylabel = 'Cryptocurrency')
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Beta Relative To Bitcoin

# %%
# DO BETA FOR MARKET AS A WHOLE, NOT JUST CRYPTOCURRENCY SECTOR: USE S&P 500 AS MARKET PROXY

# CALCULATE THE DIFFERENCE IN BETA VALUES AND HOW DRAMATIC OF A CHANGE IT IS

# %%
# making a beta series without btc so it doesn;t mess up the plots
beta_exc_btc = summary_data.iloc[8, 1:].sort_values()
type(beta_exc_btc)

beta_exc_btc.hvplot.bar(
    title = '2020 Bar: Beta relative to Bitcoin', 
    fill_color = 'cyan', hover_color = 'black',
    xlabel = 'Cryptocurrency',
    ylabel = 'Beta Value'
)
# NEED TO CHANGE Y AXIS TO NOT SHOW SCIENTIFIC NOTATION
# Out:
# :Bars   [index]   (beta)

# %%
# making a beta series without btc so it doesn;t mess up the plots
beta_exc_btc = summary_data.iloc[8, 1:].sort_values()
type(beta_exc_btc)

beta_exc_btc.hvplot.heatmap(
    title = "2020 Heatmap: Beta relative to Bitcoin", 
    fill_color = 'cyan', hover_color = 'orange', 
    ylabel = 'Cryptocurrency'

)
# NEED TO CHANGE Y AXIS TO NOT SHOW SCIENTIFIC NOTATION
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Beta Relative To Broader Market

# %%
# reading in s&p data
#reading in csv data
market_2020 = pd.read_csv(
    Path('data//S&P_2020_Closing_Monthly.csv'),
)

# display dataframe
market_2020
# Out:
#          Date  Close_Monthly
# 0     January         3230.2
# 1    February         2988.5
# 2       March         2571.3
# 3       April         2891.2
# 4         May         3061.4
# 5        June         3095.0
# 6        July         3277.4
# 7      August         3497.8
# 8   September         3348.3
# 9     October         3286.6
# 10   November         3635.9
# 11   December         3758.3

# %%
# calculate market monthly returns for 2020
# sp_market_returns
sp_returns = market_2020['Close_Monthly'].pct_change().dropna()
sp_returns
# Out:
# 1    -0.074825
# 2    -0.139602
# 3     0.124412
# 4     0.058868
# 5     0.010975
# 6     0.058934
# 7     0.067248
# 8    -0.042741
# 9    -0.018427
# 10    0.106280
# 11    0.033664
# Name: Close_Monthly, dtype: float64

# %%
# EXTRA: Calculate S&P 500 market variance based on 12 month return data (need to find that still)

"""
sp_market_var = apply after pct_change applied for sp closing price monthly data
"""
sp_market_var = sp_returns.var()

# EXTRA: Calculate S&P 500 market covariance based on 12 month return data (need to find that still)


btc_sp_cov = monthly_2020_returns['BTC'].cov(sp_returns)
eth_sp_cov = monthly_2020_returns['ETH'].cov(sp_returns)
itc_sp_cov = monthly_2020_returns['ITC'].cov(sp_returns)
ada_sp_cov = monthly_2020_returns['ADA'].cov(sp_returns)
doge_sp_cov = monthly_2020_returns['DOGE'].cov(sp_returns)
xlm_sp_cov = monthly_2020_returns['XLM'].cov(sp_returns)
xrp_sp_cov = monthly_2020_returns['XRP'].cov(sp_returns)
lisk_sp_cov = monthly_2020_returns['LISK'].cov(sp_returns)
zec_sp_cov = monthly_2020_returns['ZEC'].cov(sp_returns)
sc_sp_cov = monthly_2020_returns['SC'].cov(sp_returns)
usdt_sp_cov = monthly_2020_returns['USDT'].cov(sp_returns)
dash_sp_cov = monthly_2020_returns['DASH'].cov(sp_returns)


# EXTRA: CALCULATE BETA OF EACH CURRENCY Relative to S&P 500
"""
beta = covariance of asset to market / variance of market

use previous calculations for market variance and covariance of assets
"""


btc_sp_beta = btc_sp_cov / sp_market_var
eth_sp_beta = eth_sp_cov / sp_market_var
itc_sp_beta = itc_sp_cov / sp_market_var
ada_sp_beta = ada_sp_cov / sp_market_var
doge_sp_beta = doge_sp_cov / sp_market_var
xlm_sp_beta = xlm_sp_cov / sp_market_var
xrp_sp_beta = xrp_sp_cov / sp_market_var
lisk_sp_beta = lisk_sp_cov / sp_market_var
zec_sp_beta = zec_sp_cov / sp_market_var
sc_sp_beta = sc_sp_cov / sp_market_var
usdt_sp_beta = usdt_sp_cov / sp_market_var
dash_sp_beta = dash_sp_cov / sp_market_var

# making list of betas 
SP_Beta_list = [btc_sp_beta, eth_sp_beta, itc_sp_beta, ada_sp_beta, doge_sp_beta, xlm_sp_beta, xrp_sp_beta, lisk_sp_beta, zec_sp_beta, sc_sp_beta, usdt_sp_beta, dash_sp_beta]

# %%
# adding to main dataframe:
summary_data = summary_data.T
summary_data
summary_data['sp_beta'] = SP_Beta_list

# %%
final_summary_data = summary_data.T
final_summary_data
# Out:
#                BTC           ETH           ITC           ADA          DOGE  \
# count    11.000000  1.100000e+01  1.100000e+01  1.100000e+01  1.100000e+01
# mean      0.131258  1.775172e-01  9.258012e-02  1.787027e-01  8.518029e-02
# std       0.235589  3.074822e-01  2.915876e-01  4.061608e-01  2.256735e-01
# min      -0.247037 -3.888328e-01 -3.247893e-01 -3.533753e-01 -1.912529e-01
# 25%      -0.054424  2.458211e-02 -1.186578e-01 -1.230978e-01 -7.807496e-02
# 50%       0.094767  1.958972e-01  4.597701e-02  5.462070e-02  1.676290e-03
# 75%       0.312667  3.941191e-01  3.101354e-01  5.557478e-01  3.135961e-01
# max       0.469406  5.941935e-01  5.705840e-01  8.488244e-01  3.988449e-01
# beta      1.000000  1.389929e-09  1.652935e-09  1.587555e-09  1.192174e-09
# sp_beta   2.201037  3.223872e+00  2.642275e+00  4.094487e+00  2.208717e+00
#
#                   XLM           XRP          LISK           ZEC            SC  \
# count    1.100000e+01  1.100000e+01  1.100000e+01  1.100000e+01  1.100000e+01
# mean     1.631960e-01  1.157153e-01  2.333949e-02  3.275882e-02  1.162963e-01
# std      5.654286e-01  6.174161e-01  2.278538e-01  2.866807e-01  3.443062e-01
# min     -3.713296e-01 -6.695024e-01 -3.347009e-01 -3.687755e-01 -4.361233e-01
# 25%     -1.469157e-01 -1.368968e-01 -1.289631e-01 -1.893051e-01 -1.374875e-01
# 50%      2.067953e-03 -4.215153e-02 -1.693961e-02 -5.022214e-03  1.463415e-01
# 75%      2.486737e-01  1.502036e-01  1.821588e-01  2.595353e-01  3.935855e-01
# max      1.611343e+00  1.767407e+00  4.052997e-01  4.436032e-01  6.015625e-01
# beta     1.850027e-09  1.390747e-09  4.578543e-10  1.017422e-09  6.227065e-10
# sp_beta  4.566082e+00  3.833279e+00  1.939250e+00  3.154722e+00  2.932947e+00
#
#                  USDT          DASH
# count    1.100000e+01  1.100000e+01
# mean     2.461999e-04  1.304254e-02
# std      1.176618e-03  2.597803e-01
# min     -1.298053e-03 -2.648045e-01
# 25%     -7.495453e-04 -1.597309e-01
# 50%      4.002401e-04 -5.550812e-02
# 75%      1.199850e-03  1.281782e-01
# max      1.903236e-03  6.117811e-01
# beta    -1.823257e-12  1.086672e-09
# sp_beta -9.859001e-03  2.533829e+00

# %%
sp_beta_with_btc = final_summary_data.iloc[9, 0:].sort_values()
sp_beta_with_btc
# Out:
# USDT   -0.009859
# LISK    1.939250
# BTC     2.201037
# DOGE    2.208717
# DASH    2.533829
# ITC     2.642275
# SC      2.932947
# ZEC     3.154722
# ETH     3.223872
# XRP     3.833279
# ADA     4.094487
# XLM     4.566082
# Name: sp_beta, dtype: float64

# %%
sp_beta_with_btc.hvplot.bar(
    rot = 70,
    title = '2020 Bar: Beta relative to S&P 500',
    fill_color = 'cyan', 
    hover_color = 'black',
    xlabel = 'Cryptocurrency',
    ylabel = 'Beta Value'

)
# Out:
# :Bars   [index]   (sp_beta)

# %%
# making heatmap for s&p beta
sp_beta_with_btc.hvplot.heatmap(
    title = "2020 Heatmap: Beta relative to S&P 500",
    fill_color = 'cyan', 
    hover_color = 'orange', 
    ylabel = 'Cryptocurrency'

)
# Out:
# :HeatMap   [columns,index]   (value)

# %%
# Analysis of the difference in sensitivity compared between crypto-specific and broader market during 2020 (a black swan year)
# plot the difference in beta value between btc-specific and broader market
# could also filter for values that remained conventionally "low-beta" for both market proxies
# TETHER OBVIOUSLY WILL NOT COUNT

# %%
"""
add another heatmap that uses a dataframe with s&p monthly returns included in it, 
see what the correlation values reveal about broader relationship to market in time of extreme event
"""
# Out:
# '\nadd another heatmap that uses a dataframe with s&p monthly returns included in it, \nsee what the correlation values reveal about broader relationship to market in time of extreme event\n'

# %% [markdown]
# ## Extra Visuals

# %%
# looking at xlm and xrp in comparison and assessing sec lawsuit time range
monthly_2020_returns.hvplot(rot = 70, x = 'date', y= ['XRP', 'XLM', 'BTC'])
# Out:
# :NdOverlay   [Variable]
#    :Curve   [date]   (value)

# %%
# looking at xlm and xrp in comparison and assessing sec lawsuit time range
monthly_2020_returns.hvplot(rot = 70, x = 'date', y= ['ADA', 'BTC'])
# Out:
# :NdOverlay   [Variable]
#    :Curve   [date]   (value)
